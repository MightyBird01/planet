# %%
from skimage import io
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os
import glob
import xgboost as xgb
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
import scipy
from scipy import stats

# %matplotlib inline

path1 = '/home/gs/DataScientist/planet'
trainPath = '/train-tif'
testPath = '/test-tif'

VERBOSE_INTERVAL = 2500

NUM_BINS = 64
MAX_PIX_VAL = 65535
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# definitions

def getImageData (filePath):
    stats = []
    try:
        img = io.imread(filePath)
        r, g, b, nir = img[:, :, 0], img[:, :, 1], img[:, :, 2], img[:, :, 3]
        if not 0 in (nir+r):
            n = (nir-r) / (nir+r)
        else:
            n = np.zeros(256)
                
        hr, bins = np.histogram(r,NUM_BINS,[0, MAX_PIX_VAL])
        hg, bins = np.histogram(g,NUM_BINS,[0, MAX_PIX_VAL])
        hb, bins = np.histogram(b,NUM_BINS,[0, MAX_PIX_VAL])
        hnir, bins = np.histogram(nir,NUM_BINS,[0, MAX_PIX_VAL])
        ndvi, bins = np.histogram(n,NUM_BINS,[-1, +1])

        # stats
        stats.append( np.mean(r) )
        stats.append( np.mean(g) )
        stats.append( np.mean(b) )
        stats.append( np.mean(nir) )
        stats.append( np.std(r) )
        stats.append( np.std(g) )
        stats.append( np.std(b) )
        stats.append( np.std(nir) )
        stats.append( np.min(r) )
        stats.append( np.min(g) )
        stats.append( np.min(b) )
        stats.append( np.min(nir) )
        stats.append( np.max(r) )
        stats.append( np.max(g) )
        stats.append( np.max(b) )
        stats.append( np.max(nir) )

        stats.append( scipy.stats.kurtosis(r.ravel()) )
        stats.append( scipy.stats.kurtosis(g.ravel()) )
        stats.append( scipy.stats.kurtosis(b.ravel()) )
        stats.append( scipy.stats.kurtosis(nir.ravel()) )
        stats.append( scipy.stats.skew(r.ravel()) )
        stats.append( scipy.stats.skew(g.ravel()) )
        stats.append( scipy.stats.skew(b.ravel()) )
        stats.append( scipy.stats.skew(nir.ravel()) )
        
        # to array
        stats = np.array(stats)
        
    except Exception as  e:
        print ('{}  error reading file {}'.format(e, filePath))
        hr = np.zeros(NUM_BINS)
        hg = np.zeros(NUM_BINS)
        hb = np.zeros(NUM_BINS)
        hnir = np.zeros(NUM_BINS)
        ndvi = np.zeros(NUM_BINS)
        stats = np.zeros(24)

    r = np.concatenate((hr, hg, hb, hnir, ndvi, stats), axis = 0)
    return r

def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=2000):
    br = 0
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.01
    param['max_depth'] = 8
    param['silent'] = 1
    param['eval_metric'] = "logloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.8
    param['colsample_bytree'] = 0.8
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20, verbose_eval = 50)
        br = model.best_iteration
        #print ('best iteration for DICT: {}'.format(br))
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds, verbose_eval = 50)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model, br

# %%
print (getImageData('/home/gs/DataScientist/planet/train-tif/train_1.tif'))

# %%
# read Y_train

print ('read train y...')

try:
    Y_train = pd.read_csv(path1+'/train.csv')
except:
    path1 = '/home/ec2-user/DataScientist/planet'
    Y_train = pd.read_csv(path1+'/train.csv')

print ('Y_train lines read: {}'.format(len(Y_train)))

flatten = lambda l: [item for sublist in l for item in sublist]
labels = list(set(flatten([l.split(' ') for l in Y_train['tags'].values])))
label_map = {l: i for i, l in enumerate(labels)}
inv_label_map = {i: l for l, i in label_map.items()}
#print(label_map)
#print
#print(inv_label_map)

Y_trainDict = {}
for i, row in Y_train.iterrows():
    name = row['image_name']
    tags = row['tags']
    targets = np.zeros(17)
    for t in tags.split(' '):
        targets[label_map[t]] = 1 
    Y_trainDict[name] = targets

#print (Y_trainDict['train_0'])
#print (Y_trainDict['train_1'])
#print (Y_trainDict['train_2'])


# read train images

X_train = [] # arrays

Y_trainAll = []
X_train_id = []
lines = 0

print('Read train images')
path = os.path.join(path1+trainPath, '*.tif')
print (path)
files = glob.glob(path)
for fl in files:
    lines += 1
    if lines % VERBOSE_INTERVAL == 0:
        print ('  files read: {}'.format(lines))
    flbase = os.path.basename(fl)
    r = getImageData(fl)
    X_train.append(r)
    name = flbase.replace('.tif', '')
    X_train_id.append(name)
    Y_trainAll.append(Y_trainDict[name])


Y_trainAll = pd.DataFrame(Y_trainAll)

X_train = pd.DataFrame(X_train)
print ('X_train shape   : {}'.format(X_train.shape))
print ('Y_trainAll shape: {}'.format(Y_trainAll.shape))


X_test = [] # arrays
X_test_id = []
lines = 0 

print('Read test images')
path = os.path.join(path1+testPath, '*.tif')
print (path)
files = glob.glob(path)
for fl in files:
    lines += 1
    if lines % VERBOSE_INTERVAL == 0:
        print ('  files read: {}'.format(lines))
    flbase = os.path.basename(fl)
    r = getImageData(fl)
    X_test.append(r)
    name = flbase.replace('.tif', '')
    X_test_id.append(name)

X_test = pd.DataFrame(X_test)
print (X_test.shape)

# %%
# save data frames for later use

# Y_trainAll
# X_train
# X_test

import pickle
pickle.dump( Y_trainAll, open( "SAVE_yTrainAll.p", "wb" ) )
pickle.dump( X_train, open( "SAVE_xTrain.p", "wb" ) )
pickle.dump( X_test, open( "SAVE_xTest.p", "wb" ) )
pickle.dump( Y_trainDict, open( "SAVE_yTrainDict.p", "wb" ) )
pickle.dump( label_map, open( "SAVE_labelMap.p", "wb" ) )
pickle.dump( inv_label_map, open( "SAVE_invLabelMap.p", "wb" ) )

# %%
# load data
import pickle
Y_trainAll = pickle.load( open( "SAVE_yTrainAll.p", "rb" ) )
X_train = pickle.load( open( "SAVE_xTrain.p", "rb" ) )
X_test = pickle.load( open( "SAVE_xTest.p", "rb" ) )
Y_trainDict = pickle.load( open( "SAVE_yTrainDict.p", "rb" ) )
label_map = pickle.load( open( "SAVE_labelMap.p", "rb" ) )
inv_label_map = pickle.load( open( "SAVE_invLabelMap.p", "rb" ) )

# %%
# xgb cross validation

# save number of rounds!
brDict = {}

for i in range(0,17):
    print ('target: {} {}'.format(i, inv_label_map[i]))
    Y_train = Y_trainAll.ix[:,i]

    kf = model_selection.KFold(n_splits=3, shuffle=True, random_state=2016)
    for dev_index, val_index in kf.split(range(X_train.shape[0])):
        dev_X, val_X = X_train.iloc[dev_index], X_train.iloc[val_index]
        dev_y, val_y = Y_train.iloc[dev_index], Y_train.iloc[val_index]
        preds, model, br = runXGB(dev_X, dev_y, val_X, val_y)
        brDict[i] = br

print ('bestRounds:')
print (brDict)
# Out:
# target: 0 slash_burn
# [0]	train-logloss:0.683392	test-logloss:0.683414
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.363071	test-logloss:0.364073
# [100]	train-logloss:0.210859	test-logloss:0.212983
# [150]	train-logloss:0.129408	test-logloss:0.132794
# [200]	train-logloss:0.083166	test-logloss:0.08818
# [250]	train-logloss:0.055808	test-logloss:0.062822
# [300]	train-logloss:0.039082	test-logloss:0.048305
# [350]	train-logloss:0.028402	test-logloss:0.039946
# [400]	train-logloss:0.021518	test-logloss:0.035255
# [450]	train-logloss:0.016828	test-logloss:0.032635
# [500]	train-logloss:0.013603	test-logloss:0.03126
# [550]	train-logloss:0.011356	test-logloss:0.030596
# [600]	train-logloss:0.009624	test-logloss:0.030399
# Stopping. Best iteration:
# [606]	train-logloss:0.009456	test-logloss:0.03038
#
# [0]	train-logloss:0.68344	test-logloss:0.683397
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.364518	test-logloss:0.362861
# [100]	train-logloss:0.21301	test-logloss:0.210673
# [150]	train-logloss:0.131769	test-logloss:0.129385
# [200]	train-logloss:0.085433	test-logloss:0.083696
# [250]	train-logloss:0.057869	test-logloss:0.057277
# [300]	train-logloss:0.04085	test-logloss:0.041835
# [350]	train-logloss:0.029953	test-logloss:0.032778
# [400]	train-logloss:0.022964	test-logloss:0.027382
# [450]	train-logloss:0.018184	test-logloss:0.024178
# [500]	train-logloss:0.0149	test-logloss:0.022259
# [550]	train-logloss:0.012668	test-logloss:0.021114
# [600]	train-logloss:0.010957	test-logloss:0.020415
# [650]	train-logloss:0.009664	test-logloss:0.020044
# [700]	train-logloss:0.008611	test-logloss:0.019811
# [750]	train-logloss:0.007791	test-logloss:0.019714
# Stopping. Best iteration:
# [758]	train-logloss:0.007653	test-logloss:0.019697
#
# [0]	train-logloss:0.683392	test-logloss:0.683413
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.363113	test-logloss:0.363999
# [100]	train-logloss:0.211038	test-logloss:0.212922
# [150]	train-logloss:0.129596	test-logloss:0.132678
# [200]	train-logloss:0.08336	test-logloss:0.088015
# [250]	train-logloss:0.056031	test-logloss:0.062561
# [300]	train-logloss:0.039397	test-logloss:0.047981
# [350]	train-logloss:0.028869	test-logloss:0.039633
# [400]	train-logloss:0.021984	test-logloss:0.034886
# [450]	train-logloss:0.017295	test-logloss:0.032213
# [500]	train-logloss:0.014056	test-logloss:0.030715
# [550]	train-logloss:0.011759	test-logloss:0.02991
# [600]	train-logloss:0.010048	test-logloss:0.029527
# [650]	train-logloss:0.008742	test-logloss:0.029317
# Stopping. Best iteration:
# [660]	train-logloss:0.00853	test-logloss:0.029303
#
# target: 1 clear
# [0]	train-logloss:0.686	test-logloss:0.686294
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.445696	test-logloss:0.458192
# [100]	train-logloss:0.325849	test-logloss:0.3481
# [150]	train-logloss:0.256887	test-logloss:0.287564
# [200]	train-logloss:0.213176	test-logloss:0.252287
# [250]	train-logloss:0.185845	test-logloss:0.232236
# [300]	train-logloss:0.166633	test-logloss:0.219972
# [350]	train-logloss:0.152175	test-logloss:0.212084
# [400]	train-logloss:0.141179	test-logloss:0.207078
# [450]	train-logloss:0.131929	test-logloss:0.203689
# [500]	train-logloss:0.124724	test-logloss:0.201559
# [550]	train-logloss:0.118746	test-logloss:0.199995
# [600]	train-logloss:0.113572	test-logloss:0.198793
# [650]	train-logloss:0.109054	test-logloss:0.197935
# [700]	train-logloss:0.10457	test-logloss:0.197176
# [750]	train-logloss:0.100401	test-logloss:0.196521
# [800]	train-logloss:0.096768	test-logloss:0.196034
# [850]	train-logloss:0.093372	test-logloss:0.195652
# [900]	train-logloss:0.090345	test-logloss:0.195289
# [950]	train-logloss:0.087479	test-logloss:0.195025
# [1000]	train-logloss:0.084503	test-logloss:0.194771
# [1050]	train-logloss:0.081746	test-logloss:0.194545
# Stopping. Best iteration:
# [1060]	train-logloss:0.081245	test-logloss:0.194537
#
# [0]	train-logloss:0.685937	test-logloss:0.686136
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.447255	test-logloss:0.456258
# [100]	train-logloss:0.327341	test-logloss:0.344555
# [150]	train-logloss:0.258202	test-logloss:0.283791
# [200]	train-logloss:0.214762	test-logloss:0.248692
# [250]	train-logloss:0.186747	test-logloss:0.228066
# [300]	train-logloss:0.167734	test-logloss:0.215961
# [350]	train-logloss:0.15361	test-logloss:0.208149
# [400]	train-logloss:0.142632	test-logloss:0.203297
# [450]	train-logloss:0.134585	test-logloss:0.200478
# [500]	train-logloss:0.127313	test-logloss:0.19805
# [550]	train-logloss:0.121302	test-logloss:0.196288
# [600]	train-logloss:0.116298	test-logloss:0.195088
# [650]	train-logloss:0.111613	test-logloss:0.194176
# [700]	train-logloss:0.107395	test-logloss:0.193337
# [750]	train-logloss:0.10327	test-logloss:0.192629
# [800]	train-logloss:0.099448	test-logloss:0.192103
# [850]	train-logloss:0.095741	test-logloss:0.191642
# [900]	train-logloss:0.092415	test-logloss:0.191325
# [950]	train-logloss:0.089102	test-logloss:0.191003
# [1000]	train-logloss:0.086007	test-logloss:0.190682
# [1050]	train-logloss:0.082929	test-logloss:0.190534
# [1100]	train-logloss:0.079993	test-logloss:0.190407
# Stopping. Best iteration:
# [1093]	train-logloss:0.080339	test-logloss:0.19039
#
# [0]	train-logloss:0.685873	test-logloss:0.686247
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.445513	test-logloss:0.460678
# [100]	train-logloss:0.324001	test-logloss:0.351
# [150]	train-logloss:0.254419	test-logloss:0.291201
# [200]	train-logloss:0.210735	test-logloss:0.256773
# [250]	train-logloss:0.182647	test-logloss:0.236842
# [300]	train-logloss:0.163646	test-logloss:0.225381
# [350]	train-logloss:0.149834	test-logloss:0.218179
# [400]	train-logloss:0.13879	test-logloss:0.21342
# [450]	train-logloss:0.129831	test-logloss:0.210263
# [500]	train-logloss:0.122592	test-logloss:0.208123
# [550]	train-logloss:0.116556	test-logloss:0.206563
# [600]	train-logloss:0.111476	test-logloss:0.205364
# [650]	train-logloss:0.107	test-logloss:0.204467
# [700]	train-logloss:0.102828	test-logloss:0.203684
# [750]	train-logloss:0.098735	test-logloss:0.203119
# [800]	train-logloss:0.094424	test-logloss:0.202614
# [850]	train-logloss:0.091103	test-logloss:0.202129
# [900]	train-logloss:0.087651	test-logloss:0.201796
# [950]	train-logloss:0.084881	test-logloss:0.201587
# [1000]	train-logloss:0.082002	test-logloss:0.201361
# [1050]	train-logloss:0.079264	test-logloss:0.201179
# Stopping. Best iteration:
# [1072]	train-logloss:0.078012	test-logloss:0.201152
#
# target: 2 blooming
# [0]	train-logloss:0.683545	test-logloss:0.683522
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367994	test-logloss:0.367482
# [100]	train-logloss:0.218246	test-logloss:0.217838
# [150]	train-logloss:0.138101	test-logloss:0.138359
# [200]	train-logloss:0.092484	test-logloss:0.093935
# [250]	train-logloss:0.065258	test-logloss:0.068454
# [300]	train-logloss:0.048476	test-logloss:0.053626
# [350]	train-logloss:0.037729	test-logloss:0.044925
# [400]	train-logloss:0.030869	test-logloss:0.039868
# [450]	train-logloss:0.026152	test-logloss:0.03687
# [500]	train-logloss:0.022894	test-logloss:0.035088
# [550]	train-logloss:0.020539	test-logloss:0.034103
# [600]	train-logloss:0.018722	test-logloss:0.033511
# [650]	train-logloss:0.01736	test-logloss:0.033214
# [700]	train-logloss:0.016107	test-logloss:0.033038
# [750]	train-logloss:0.014891	test-logloss:0.032953
# Stopping. Best iteration:
# [760]	train-logloss:0.014683	test-logloss:0.032945
#
# [0]	train-logloss:0.68351	test-logloss:0.683535
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367039	test-logloss:0.368221
# [100]	train-logloss:0.216826	test-logloss:0.219364
# [150]	train-logloss:0.136453	test-logloss:0.140642
# [200]	train-logloss:0.090971	test-logloss:0.097007
# [250]	train-logloss:0.064084	test-logloss:0.072353
# [300]	train-logloss:0.047472	test-logloss:0.058293
# [350]	train-logloss:0.036952	test-logloss:0.050274
# [400]	train-logloss:0.030178	test-logloss:0.045757
# [450]	train-logloss:0.025617	test-logloss:0.043338
# [500]	train-logloss:0.022479	test-logloss:0.042018
# [550]	train-logloss:0.020101	test-logloss:0.041372
# [600]	train-logloss:0.018305	test-logloss:0.041133
# [650]	train-logloss:0.01688	test-logloss:0.041038
# Stopping. Best iteration:
# [656]	train-logloss:0.016705	test-logloss:0.041016
#
# [0]	train-logloss:0.683519	test-logloss:0.683518
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.36741	test-logloss:0.367746
# [100]	train-logloss:0.217275	test-logloss:0.218467
# [150]	train-logloss:0.136717	test-logloss:0.139335
# [200]	train-logloss:0.090645	test-logloss:0.095334
# [250]	train-logloss:0.06343	test-logloss:0.070404
# [300]	train-logloss:0.046679	test-logloss:0.056219
# [350]	train-logloss:0.036176	test-logloss:0.04822
# [400]	train-logloss:0.029255	test-logloss:0.043731
# [450]	train-logloss:0.024737	test-logloss:0.0413
# [500]	train-logloss:0.021725	test-logloss:0.039931
# [550]	train-logloss:0.019398	test-logloss:0.039181
# [600]	train-logloss:0.017618	test-logloss:0.038842
# [650]	train-logloss:0.016119	test-logloss:0.03866
# [700]	train-logloss:0.014879	test-logloss:0.03856
# Stopping. Best iteration:
# [718]	train-logloss:0.014427	test-logloss:0.038551
#
# target: 3 primary
# [0]	train-logloss:0.684221	test-logloss:0.684444
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.389949	test-logloss:0.39942
# [100]	train-logloss:0.247028	test-logloss:0.264464
# [150]	train-logloss:0.168267	test-logloss:0.192854
# [200]	train-logloss:0.122028	test-logloss:0.152688
# [250]	train-logloss:0.093557	test-logloss:0.129703
# [300]	train-logloss:0.075823	test-logloss:0.116441
# [350]	train-logloss:0.064411	test-logloss:0.109096
# [400]	train-logloss:0.056668	test-logloss:0.104917
# [450]	train-logloss:0.051122	test-logloss:0.102639
# [500]	train-logloss:0.047183	test-logloss:0.101392
# [550]	train-logloss:0.044244	test-logloss:0.100763
# [600]	train-logloss:0.041817	test-logloss:0.10045
# [650]	train-logloss:0.039803	test-logloss:0.100337
# Stopping. Best iteration:
# [645]	train-logloss:0.040006	test-logloss:0.100304
#
# [0]	train-logloss:0.684253	test-logloss:0.684443
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.390674	test-logloss:0.398443
# [100]	train-logloss:0.248206	test-logloss:0.26249
# [150]	train-logloss:0.169832	test-logloss:0.190019
# [200]	train-logloss:0.123618	test-logloss:0.14948
# [250]	train-logloss:0.095095	test-logloss:0.126146
# [300]	train-logloss:0.077175	test-logloss:0.112529
# [350]	train-logloss:0.065534	test-logloss:0.104692
# [400]	train-logloss:0.057671	test-logloss:0.100184
# [450]	train-logloss:0.052336	test-logloss:0.097609
# [500]	train-logloss:0.048541	test-logloss:0.096216
# [550]	train-logloss:0.045564	test-logloss:0.095409
# [600]	train-logloss:0.043321	test-logloss:0.095031
# [650]	train-logloss:0.041254	test-logloss:0.094928
# Stopping. Best iteration:
# [655]	train-logloss:0.041067	test-logloss:0.094911
#
# [0]	train-logloss:0.684258	test-logloss:0.68447
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.390639	test-logloss:0.398859
# [100]	train-logloss:0.248107	test-logloss:0.263217
# [150]	train-logloss:0.169691	test-logloss:0.190946
# [200]	train-logloss:0.123347	test-logloss:0.150298
# [250]	train-logloss:0.094463	test-logloss:0.126844
# [300]	train-logloss:0.076504	test-logloss:0.113216
# [350]	train-logloss:0.064913	test-logloss:0.105422
# [400]	train-logloss:0.057235	test-logloss:0.100943
# [450]	train-logloss:0.051762	test-logloss:0.098358
# [500]	train-logloss:0.048027	test-logloss:0.096868
# [550]	train-logloss:0.045073	test-logloss:0.095988
# [600]	train-logloss:0.042849	test-logloss:0.095537
# [650]	train-logloss:0.0407	test-logloss:0.09522
# [700]	train-logloss:0.038815	test-logloss:0.095069
# [750]	train-logloss:0.037174	test-logloss:0.094999
# Stopping. Best iteration:
# [730]	train-logloss:0.03785	test-logloss:0.094952
#
# target: 4 cloudy
# [0]	train-logloss:0.68393	test-logloss:0.684128
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.379065	test-logloss:0.387001
# [100]	train-logloss:0.231101	test-logloss:0.245168
# [150]	train-logloss:0.149711	test-logloss:0.169279
# [200]	train-logloss:0.10205	test-logloss:0.126298
# [250]	train-logloss:0.072808	test-logloss:0.101404
# [300]	train-logloss:0.054387	test-logloss:0.086874
# [350]	train-logloss:0.04253	test-logloss:0.078215
# [400]	train-logloss:0.03471	test-logloss:0.073194
# [450]	train-logloss:0.029284	test-logloss:0.070336
# [500]	train-logloss:0.025502	test-logloss:0.068785
# [550]	train-logloss:0.022785	test-logloss:0.067949
# [600]	train-logloss:0.0207	test-logloss:0.067567
# [650]	train-logloss:0.019055	test-logloss:0.067485
# Stopping. Best iteration:
# [652]	train-logloss:0.018999	test-logloss:0.067465
#
# [0]	train-logloss:0.683907	test-logloss:0.684111
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.37924	test-logloss:0.386595
# [100]	train-logloss:0.231406	test-logloss:0.244418
# [150]	train-logloss:0.150467	test-logloss:0.168081
# [200]	train-logloss:0.10302	test-logloss:0.124748
# [250]	train-logloss:0.073976	test-logloss:0.099221
# [300]	train-logloss:0.055638	test-logloss:0.084019
# [350]	train-logloss:0.043882	test-logloss:0.074963
# [400]	train-logloss:0.036008	test-logloss:0.069465
# [450]	train-logloss:0.030638	test-logloss:0.066194
# [500]	train-logloss:0.026801	test-logloss:0.064222
# [550]	train-logloss:0.024106	test-logloss:0.063035
# [600]	train-logloss:0.022181	test-logloss:0.062304
# [650]	train-logloss:0.020628	test-logloss:0.06185
# [700]	train-logloss:0.019319	test-logloss:0.061499
# [750]	train-logloss:0.018152	test-logloss:0.061195
# [800]	train-logloss:0.017106	test-logloss:0.061088
# Stopping. Best iteration:
# [817]	train-logloss:0.016733	test-logloss:0.061038
#
# [0]	train-logloss:0.683923	test-logloss:0.684086
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.379692	test-logloss:0.386331
# [100]	train-logloss:0.232184	test-logloss:0.243937
# [150]	train-logloss:0.151177	test-logloss:0.1674
# [200]	train-logloss:0.103401	test-logloss:0.123714
# [250]	train-logloss:0.074127	test-logloss:0.098007
# [300]	train-logloss:0.055686	test-logloss:0.082784
# [350]	train-logloss:0.043975	test-logloss:0.07376
# [400]	train-logloss:0.03617	test-logloss:0.068217
# [450]	train-logloss:0.030747	test-logloss:0.064806
# [500]	train-logloss:0.026973	test-logloss:0.062721
# [550]	train-logloss:0.02422	test-logloss:0.061436
# [600]	train-logloss:0.022327	test-logloss:0.060583
# [650]	train-logloss:0.020769	test-logloss:0.060062
# [700]	train-logloss:0.019554	test-logloss:0.059743
# [750]	train-logloss:0.018398	test-logloss:0.059489
# [800]	train-logloss:0.017381	test-logloss:0.059371
# Stopping. Best iteration:
# [819]	train-logloss:0.017011	test-logloss:0.059308
#
# target: 5 conventional_mine
# [0]	train-logloss:0.683286	test-logloss:0.683305
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359275	test-logloss:0.360141
# [100]	train-logloss:0.205029	test-logloss:0.206685
# [150]	train-logloss:0.1222	test-logloss:0.124665
# [200]	train-logloss:0.074994	test-logloss:0.078447
# [250]	train-logloss:0.047227	test-logloss:0.051678
# [300]	train-logloss:0.030484	test-logloss:0.035941
# [350]	train-logloss:0.020245	test-logloss:0.026638
# [400]	train-logloss:0.01385	test-logloss:0.021206
# [450]	train-logloss:0.009824	test-logloss:0.018044
# [500]	train-logloss:0.007234	test-logloss:0.016195
# [550]	train-logloss:0.005513	test-logloss:0.015195
# [600]	train-logloss:0.004334	test-logloss:0.01461
# [650]	train-logloss:0.003502	test-logloss:0.014266
# [700]	train-logloss:0.002889	test-logloss:0.014069
# [750]	train-logloss:0.002438	test-logloss:0.013979
# [800]	train-logloss:0.002083	test-logloss:0.013966
# Stopping. Best iteration:
# [813]	train-logloss:0.002005	test-logloss:0.013955
#
# [0]	train-logloss:0.683314	test-logloss:0.683295
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.360256	test-logloss:0.359483
# [100]	train-logloss:0.206247	test-logloss:0.205304
# [150]	train-logloss:0.123278	test-logloss:0.122632
# [200]	train-logloss:0.075907	test-logloss:0.075872
# [250]	train-logloss:0.047951	test-logloss:0.048642
# [300]	train-logloss:0.0311	test-logloss:0.032608
# [350]	train-logloss:0.020776	test-logloss:0.023091
# [400]	train-logloss:0.014333	test-logloss:0.017466
# [450]	train-logloss:0.010239	test-logloss:0.014131
# [500]	train-logloss:0.00759	test-logloss:0.012166
# [550]	train-logloss:0.005822	test-logloss:0.011038
# [600]	train-logloss:0.004614	test-logloss:0.010391
# [650]	train-logloss:0.003752	test-logloss:0.010035
# [700]	train-logloss:0.003108	test-logloss:0.009801
# [750]	train-logloss:0.002629	test-logloss:0.009697
# [800]	train-logloss:0.002265	test-logloss:0.009664
# Stopping. Best iteration:
# [792]	train-logloss:0.002321	test-logloss:0.009658
#
# [0]	train-logloss:0.683295	test-logloss:0.683294
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359866	test-logloss:0.359835
# [100]	train-logloss:0.205971	test-logloss:0.206008
# [150]	train-logloss:0.123055	test-logloss:0.123552
# [200]	train-logloss:0.075676	test-logloss:0.076986
# [250]	train-logloss:0.047754	test-logloss:0.049867
# [300]	train-logloss:0.030987	test-logloss:0.033954
# [350]	train-logloss:0.020688	test-logloss:0.024534
# [400]	train-logloss:0.014262	test-logloss:0.018951
# [450]	train-logloss:0.010183	test-logloss:0.015681
# [500]	train-logloss:0.007551	test-logloss:0.013766
# [550]	train-logloss:0.005775	test-logloss:0.012695
# [600]	train-logloss:0.004551	test-logloss:0.012123
# [650]	train-logloss:0.003696	test-logloss:0.011822
# [700]	train-logloss:0.003053	test-logloss:0.011712
# Stopping. Best iteration:
# [725]	train-logloss:0.002795	test-logloss:0.011673
#
# target: 6 water
# [0]	train-logloss:0.686489	test-logloss:0.686818
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.464411	test-logloss:0.478561
# [100]	train-logloss:0.355123	test-logloss:0.381115
# [150]	train-logloss:0.293215	test-logloss:0.330177
# [200]	train-logloss:0.255101	test-logloss:0.302312
# [250]	train-logloss:0.229466	test-logloss:0.286441
# [300]	train-logloss:0.212059	test-logloss:0.277627
# [350]	train-logloss:0.198863	test-logloss:0.27238
# [400]	train-logloss:0.188668	test-logloss:0.269234
# [450]	train-logloss:0.180589	test-logloss:0.267278
# [500]	train-logloss:0.173279	test-logloss:0.265728
# [550]	train-logloss:0.167276	test-logloss:0.264794
# [600]	train-logloss:0.161526	test-logloss:0.264141
# [650]	train-logloss:0.157073	test-logloss:0.263714
# [700]	train-logloss:0.152689	test-logloss:0.263274
# [750]	train-logloss:0.148903	test-logloss:0.263006
# Stopping. Best iteration:
# [778]	train-logloss:0.146429	test-logloss:0.262862
#
# [0]	train-logloss:0.686616	test-logloss:0.686797
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.465394	test-logloss:0.476442
# [100]	train-logloss:0.355931	test-logloss:0.377197
# [150]	train-logloss:0.294066	test-logloss:0.325491
# [200]	train-logloss:0.25563	test-logloss:0.297448
# [250]	train-logloss:0.230125	test-logloss:0.281805
# [300]	train-logloss:0.212155	test-logloss:0.272625
# [350]	train-logloss:0.198886	test-logloss:0.2672
# [400]	train-logloss:0.188698	test-logloss:0.264011
# [450]	train-logloss:0.180337	test-logloss:0.262121
# [500]	train-logloss:0.17271	test-logloss:0.260746
# [550]	train-logloss:0.166831	test-logloss:0.259819
# [600]	train-logloss:0.161465	test-logloss:0.259438
# [650]	train-logloss:0.156479	test-logloss:0.258913
# [700]	train-logloss:0.152289	test-logloss:0.258524
# [750]	train-logloss:0.14808	test-logloss:0.258219
# [800]	train-logloss:0.143865	test-logloss:0.258056
# [850]	train-logloss:0.139967	test-logloss:0.257838
# [900]	train-logloss:0.13675	test-logloss:0.25773
# [950]	train-logloss:0.133235	test-logloss:0.257583
# Stopping. Best iteration:
# [953]	train-logloss:0.133114	test-logloss:0.257568
#
# [0]	train-logloss:0.686514	test-logloss:0.686814
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.464464	test-logloss:0.479824
# [100]	train-logloss:0.35461	test-logloss:0.382818
# [150]	train-logloss:0.292597	test-logloss:0.332527
# [200]	train-logloss:0.253925	test-logloss:0.304615
# [250]	train-logloss:0.227934	test-logloss:0.288866
# [300]	train-logloss:0.20975	test-logloss:0.280009
# [350]	train-logloss:0.195986	test-logloss:0.274533
# [400]	train-logloss:0.185614	test-logloss:0.271247
# [450]	train-logloss:0.177535	test-logloss:0.269192
# [500]	train-logloss:0.171004	test-logloss:0.267862
# [550]	train-logloss:0.165346	test-logloss:0.26699
# [600]	train-logloss:0.15934	test-logloss:0.266116
# [650]	train-logloss:0.154897	test-logloss:0.265707
# [700]	train-logloss:0.150929	test-logloss:0.265341
# [750]	train-logloss:0.146153	test-logloss:0.265029
# [800]	train-logloss:0.142651	test-logloss:0.264804
# [850]	train-logloss:0.138927	test-logloss:0.264607
# [900]	train-logloss:0.135121	test-logloss:0.264422
# Stopping. Best iteration:
# [895]	train-logloss:0.135538	test-logloss:0.264399
#
# target: 7 haze
# [0]	train-logloss:0.684502	test-logloss:0.684723
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.397422	test-logloss:0.408552
# [100]	train-logloss:0.257988	test-logloss:0.277725
# [150]	train-logloss:0.181464	test-logloss:0.208334
# [200]	train-logloss:0.13656	test-logloss:0.169711
# [250]	train-logloss:0.10903	test-logloss:0.147523
# [300]	train-logloss:0.091581	test-logloss:0.13433
# [350]	train-logloss:0.080181	test-logloss:0.12686
# [400]	train-logloss:0.072382	test-logloss:0.122471
# [450]	train-logloss:0.066569	test-logloss:0.119919
# [500]	train-logloss:0.062213	test-logloss:0.118461
# [550]	train-logloss:0.058746	test-logloss:0.117694
# [600]	train-logloss:0.055761	test-logloss:0.117292
# [650]	train-logloss:0.053078	test-logloss:0.117042
# [700]	train-logloss:0.050665	test-logloss:0.116912
# [750]	train-logloss:0.048375	test-logloss:0.116824
# Stopping. Best iteration:
# [763]	train-logloss:0.047841	test-logloss:0.116806
#
# [0]	train-logloss:0.684543	test-logloss:0.684692
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.399289	test-logloss:0.405975
# [100]	train-logloss:0.26079	test-logloss:0.273733
# [150]	train-logloss:0.184566	test-logloss:0.203474
# [200]	train-logloss:0.139877	test-logloss:0.164336
# [250]	train-logloss:0.11239	test-logloss:0.141727
# [300]	train-logloss:0.095147	test-logloss:0.128631
# [350]	train-logloss:0.084007	test-logloss:0.121133
# [400]	train-logloss:0.076348	test-logloss:0.116716
# [450]	train-logloss:0.070823	test-logloss:0.114307
# [500]	train-logloss:0.066375	test-logloss:0.112957
# [550]	train-logloss:0.06293	test-logloss:0.112126
# [600]	train-logloss:0.059955	test-logloss:0.111639
# [650]	train-logloss:0.057332	test-logloss:0.111393
# [700]	train-logloss:0.054513	test-logloss:0.111245
# Stopping. Best iteration:
# [705]	train-logloss:0.054214	test-logloss:0.111208
#
# [0]	train-logloss:0.684521	test-logloss:0.684708
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.398918	test-logloss:0.406965
# [100]	train-logloss:0.260229	test-logloss:0.275147
# [150]	train-logloss:0.183977	test-logloss:0.205097
# [200]	train-logloss:0.139411	test-logloss:0.16589
# [250]	train-logloss:0.112115	test-logloss:0.143556
# [300]	train-logloss:0.094392	test-logloss:0.130263
# [350]	train-logloss:0.082601	test-logloss:0.122495
# [400]	train-logloss:0.074542	test-logloss:0.118024
# [450]	train-logloss:0.068396	test-logloss:0.11545
# [500]	train-logloss:0.063916	test-logloss:0.113988
# [550]	train-logloss:0.06043	test-logloss:0.113127
# [600]	train-logloss:0.057338	test-logloss:0.112675
# [650]	train-logloss:0.054475	test-logloss:0.112408
# [700]	train-logloss:0.051814	test-logloss:0.112377
# [750]	train-logloss:0.049503	test-logloss:0.112384
# Stopping. Best iteration:
# [741]	train-logloss:0.049911	test-logloss:0.112328
#
# target: 8 cultivation
# [0]	train-logloss:0.686289	test-logloss:0.686489
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.459127	test-logloss:0.468236
# [100]	train-logloss:0.349982	test-logloss:0.367249
# [150]	train-logloss:0.290315	test-logloss:0.315623
# [200]	train-logloss:0.255295	test-logloss:0.28835
# [250]	train-logloss:0.232689	test-logloss:0.273513
# [300]	train-logloss:0.21751	test-logloss:0.26527
# [350]	train-logloss:0.20628	test-logloss:0.260693
# [400]	train-logloss:0.197702	test-logloss:0.258043
# [450]	train-logloss:0.190189	test-logloss:0.256368
# [500]	train-logloss:0.183482	test-logloss:0.25541
# [550]	train-logloss:0.177768	test-logloss:0.254695
# [600]	train-logloss:0.171926	test-logloss:0.254272
# Stopping. Best iteration:
# [606]	train-logloss:0.171177	test-logloss:0.254234
#
# [0]	train-logloss:0.686281	test-logloss:0.686467
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.460149	test-logloss:0.46885
# [100]	train-logloss:0.35142	test-logloss:0.368039
# [150]	train-logloss:0.292159	test-logloss:0.316508
# [200]	train-logloss:0.25675	test-logloss:0.289001
# [250]	train-logloss:0.234334	test-logloss:0.273729
# [300]	train-logloss:0.21931	test-logloss:0.26527
# [350]	train-logloss:0.208287	test-logloss:0.260428
# [400]	train-logloss:0.199488	test-logloss:0.25773
# [450]	train-logloss:0.191735	test-logloss:0.255969
# [500]	train-logloss:0.185051	test-logloss:0.254924
# [550]	train-logloss:0.179099	test-logloss:0.254361
# [600]	train-logloss:0.174065	test-logloss:0.25399
# [650]	train-logloss:0.168622	test-logloss:0.253669
# [700]	train-logloss:0.163709	test-logloss:0.253384
# [750]	train-logloss:0.159347	test-logloss:0.253211
# [800]	train-logloss:0.154737	test-logloss:0.253078
# Stopping. Best iteration:
# [805]	train-logloss:0.154292	test-logloss:0.253045
#
# [0]	train-logloss:0.686264	test-logloss:0.686532
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.457656	test-logloss:0.470248
# [100]	train-logloss:0.347136	test-logloss:0.37088
# [150]	train-logloss:0.286929	test-logloss:0.320758
# [200]	train-logloss:0.25107	test-logloss:0.294408
# [250]	train-logloss:0.227921	test-logloss:0.280561
# [300]	train-logloss:0.212297	test-logloss:0.273037
# [350]	train-logloss:0.200882	test-logloss:0.268837
# [400]	train-logloss:0.192107	test-logloss:0.266721
# [450]	train-logloss:0.185198	test-logloss:0.265537
# [500]	train-logloss:0.178486	test-logloss:0.265068
# [550]	train-logloss:0.17252	test-logloss:0.26474
# Stopping. Best iteration:
# [578]	train-logloss:0.169779	test-logloss:0.26462
#
# target: 9 partly_cloudy
# [0]	train-logloss:0.685255	test-logloss:0.685556
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.421052	test-logloss:0.434118
# [100]	train-logloss:0.290826	test-logloss:0.314255
# [150]	train-logloss:0.218155	test-logloss:0.250161
# [200]	train-logloss:0.174778	test-logloss:0.214207
# [250]	train-logloss:0.146828	test-logloss:0.19349
# [300]	train-logloss:0.128684	test-logloss:0.181314
# [350]	train-logloss:0.115974	test-logloss:0.17413
# [400]	train-logloss:0.106581	test-logloss:0.169876
# [450]	train-logloss:0.099315	test-logloss:0.167244
# [500]	train-logloss:0.093842	test-logloss:0.165511
# [550]	train-logloss:0.089618	test-logloss:0.164432
# [600]	train-logloss:0.08615	test-logloss:0.163724
# [650]	train-logloss:0.083202	test-logloss:0.163144
# [700]	train-logloss:0.08018	test-logloss:0.162675
# [750]	train-logloss:0.076851	test-logloss:0.162156
# [800]	train-logloss:0.073692	test-logloss:0.161845
# [850]	train-logloss:0.070978	test-logloss:0.161679
# [900]	train-logloss:0.068259	test-logloss:0.161516
# [950]	train-logloss:0.065641	test-logloss:0.161356
# Stopping. Best iteration:
# [948]	train-logloss:0.065764	test-logloss:0.161341
#
# [0]	train-logloss:0.685343	test-logloss:0.68555
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.42316	test-logloss:0.433356
# [100]	train-logloss:0.293119	test-logloss:0.312034
# [150]	train-logloss:0.220216	test-logloss:0.247012
# [200]	train-logloss:0.177038	test-logloss:0.210723
# [250]	train-logloss:0.149443	test-logloss:0.189663
# [300]	train-logloss:0.131148	test-logloss:0.177426
# [350]	train-logloss:0.118177	test-logloss:0.169987
# [400]	train-logloss:0.108964	test-logloss:0.165707
# [450]	train-logloss:0.102238	test-logloss:0.163063
# [500]	train-logloss:0.097232	test-logloss:0.161408
# [550]	train-logloss:0.093532	test-logloss:0.160336
# [600]	train-logloss:0.089701	test-logloss:0.15952
# [650]	train-logloss:0.086338	test-logloss:0.158864
# [700]	train-logloss:0.083289	test-logloss:0.158243
# [750]	train-logloss:0.080118	test-logloss:0.157753
# [800]	train-logloss:0.076789	test-logloss:0.157284
# [850]	train-logloss:0.073936	test-logloss:0.156992
# [900]	train-logloss:0.071138	test-logloss:0.156679
# [950]	train-logloss:0.068427	test-logloss:0.156544
# [1000]	train-logloss:0.065951	test-logloss:0.156422
# [1050]	train-logloss:0.06369	test-logloss:0.156271
# [1100]	train-logloss:0.061397	test-logloss:0.156175
# Stopping. Best iteration:
# [1094]	train-logloss:0.061633	test-logloss:0.156156
#
# [0]	train-logloss:0.685282	test-logloss:0.685578
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.420767	test-logloss:0.434389
# [100]	train-logloss:0.29012	test-logloss:0.314311
# [150]	train-logloss:0.217158	test-logloss:0.2506
# [200]	train-logloss:0.172989	test-logloss:0.214676
# [250]	train-logloss:0.14509	test-logloss:0.194292
# [300]	train-logloss:0.126436	test-logloss:0.182604
# [350]	train-logloss:0.11373	test-logloss:0.175705
# [400]	train-logloss:0.104412	test-logloss:0.171673
# [450]	train-logloss:0.097427	test-logloss:0.169168
# [500]	train-logloss:0.092014	test-logloss:0.167545
# [550]	train-logloss:0.088109	test-logloss:0.166661
# [600]	train-logloss:0.084523	test-logloss:0.165985
# [650]	train-logloss:0.08142	test-logloss:0.165512
# [700]	train-logloss:0.078296	test-logloss:0.165058
# [750]	train-logloss:0.075208	test-logloss:0.164756
# [800]	train-logloss:0.072044	test-logloss:0.164416
# [850]	train-logloss:0.069248	test-logloss:0.164167
# [900]	train-logloss:0.06672	test-logloss:0.16397
# [950]	train-logloss:0.064386	test-logloss:0.163877
# [1000]	train-logloss:0.062123	test-logloss:0.163824
# Stopping. Best iteration:
# [980]	train-logloss:0.062996	test-logloss:0.163802
#
# target: 10 artisinal_mine
# [0]	train-logloss:0.683392	test-logloss:0.683446
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.36204	test-logloss:0.363317
# [100]	train-logloss:0.208084	test-logloss:0.210454
# [150]	train-logloss:0.124778	test-logloss:0.128174
# [200]	train-logloss:0.077185	test-logloss:0.081562
# [250]	train-logloss:0.048855	test-logloss:0.054386
# [300]	train-logloss:0.031759	test-logloss:0.038421
# [350]	train-logloss:0.021265	test-logloss:0.028968
# [400]	train-logloss:0.014705	test-logloss:0.023374
# [450]	train-logloss:0.010592	test-logloss:0.020085
# [500]	train-logloss:0.00792	test-logloss:0.018107
# [550]	train-logloss:0.006137	test-logloss:0.016959
# [600]	train-logloss:0.004931	test-logloss:0.016293
# [650]	train-logloss:0.00409	test-logloss:0.015889
# [700]	train-logloss:0.00348	test-logloss:0.015683
# [750]	train-logloss:0.003013	test-logloss:0.015557
# [800]	train-logloss:0.00264	test-logloss:0.01548
# [850]	train-logloss:0.002328	test-logloss:0.015461
# Stopping. Best iteration:
# [843]	train-logloss:0.002369	test-logloss:0.015454
#
# [0]	train-logloss:0.683368	test-logloss:0.683417
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.361951	test-logloss:0.363584
# [100]	train-logloss:0.208057	test-logloss:0.211085
# [150]	train-logloss:0.124763	test-logloss:0.129197
# [200]	train-logloss:0.077058	test-logloss:0.082799
# [250]	train-logloss:0.048818	test-logloss:0.055803
# [300]	train-logloss:0.031776	test-logloss:0.040022
# [350]	train-logloss:0.021314	test-logloss:0.030715
# [400]	train-logloss:0.014841	test-logloss:0.025275
# [450]	train-logloss:0.010729	test-logloss:0.022092
# [500]	train-logloss:0.008045	test-logloss:0.020216
# [550]	train-logloss:0.006271	test-logloss:0.019126
# [600]	train-logloss:0.00506	test-logloss:0.018512
# [650]	train-logloss:0.0042	test-logloss:0.018165
# [700]	train-logloss:0.003568	test-logloss:0.01798
# [750]	train-logloss:0.003057	test-logloss:0.0179
# [800]	train-logloss:0.002676	test-logloss:0.017842
# Stopping. Best iteration:
# [792]	train-logloss:0.002734	test-logloss:0.017838
#
# [0]	train-logloss:0.683374	test-logloss:0.68343
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.361854	test-logloss:0.363854
# [100]	train-logloss:0.20814	test-logloss:0.211486
# [150]	train-logloss:0.125158	test-logloss:0.129757
# [200]	train-logloss:0.077464	test-logloss:0.08322
# [250]	train-logloss:0.049321	test-logloss:0.056174
# [300]	train-logloss:0.032328	test-logloss:0.040146
# [350]	train-logloss:0.021833	test-logloss:0.030574
# [400]	train-logloss:0.015242	test-logloss:0.024896
# [450]	train-logloss:0.011069	test-logloss:0.021503
# [500]	train-logloss:0.008311	test-logloss:0.019459
# [550]	train-logloss:0.006485	test-logloss:0.018178
# [600]	train-logloss:0.005246	test-logloss:0.017389
# [650]	train-logloss:0.004378	test-logloss:0.016833
# [700]	train-logloss:0.003736	test-logloss:0.016522
# [750]	train-logloss:0.003244	test-logloss:0.016373
# [800]	train-logloss:0.00286	test-logloss:0.016246
# [850]	train-logloss:0.002537	test-logloss:0.016183
# [900]	train-logloss:0.002277	test-logloss:0.01616
# Stopping. Best iteration:
# [891]	train-logloss:0.002321	test-logloss:0.016146
#
# target: 11 habitation
# [0]	train-logloss:0.6851	test-logloss:0.68531
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.419911	test-logloss:0.427564
# [100]	train-logloss:0.291361	test-logloss:0.306274
# [150]	train-logloss:0.221307	test-logloss:0.242779
# [200]	train-logloss:0.180796	test-logloss:0.208289
# [250]	train-logloss:0.154803	test-logloss:0.188703
# [300]	train-logloss:0.137697	test-logloss:0.17729
# [350]	train-logloss:0.126222	test-logloss:0.170798
# [400]	train-logloss:0.118289	test-logloss:0.167021
# [450]	train-logloss:0.112005	test-logloss:0.164797
# [500]	train-logloss:0.106773	test-logloss:0.163359
# [550]	train-logloss:0.101854	test-logloss:0.162576
# [600]	train-logloss:0.097445	test-logloss:0.162021
# [650]	train-logloss:0.093164	test-logloss:0.161504
# [700]	train-logloss:0.08939	test-logloss:0.161233
# [750]	train-logloss:0.085839	test-logloss:0.161036
# [800]	train-logloss:0.082623	test-logloss:0.160805
# [850]	train-logloss:0.079118	test-logloss:0.160697
# [900]	train-logloss:0.076316	test-logloss:0.16067
# Stopping. Best iteration:
# [881]	train-logloss:0.077465	test-logloss:0.160625
#
# [0]	train-logloss:0.685145	test-logloss:0.685352
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.419143	test-logloss:0.428335
# [100]	train-logloss:0.290861	test-logloss:0.307577
# [150]	train-logloss:0.220588	test-logloss:0.244272
# [200]	train-logloss:0.178657	test-logloss:0.209097
# [250]	train-logloss:0.152564	test-logloss:0.189331
# [300]	train-logloss:0.135819	test-logloss:0.178035
# [350]	train-logloss:0.124608	test-logloss:0.171634
# [400]	train-logloss:0.116709	test-logloss:0.167994
# [450]	train-logloss:0.110477	test-logloss:0.165724
# [500]	train-logloss:0.105154	test-logloss:0.164352
# [550]	train-logloss:0.100396	test-logloss:0.163533
# [600]	train-logloss:0.096268	test-logloss:0.163033
# [650]	train-logloss:0.092271	test-logloss:0.162705
# [700]	train-logloss:0.088426	test-logloss:0.162502
# [750]	train-logloss:0.084924	test-logloss:0.162383
# [800]	train-logloss:0.081664	test-logloss:0.162272
# Stopping. Best iteration:
# [785]	train-logloss:0.082637	test-logloss:0.162258
#
# [0]	train-logloss:0.6851	test-logloss:0.685338
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.418296	test-logloss:0.429269
# [100]	train-logloss:0.289308	test-logloss:0.308556
# [150]	train-logloss:0.218596	test-logloss:0.24512
# [200]	train-logloss:0.17716	test-logloss:0.210446
# [250]	train-logloss:0.151343	test-logloss:0.190633
# [300]	train-logloss:0.134773	test-logloss:0.179435
# [350]	train-logloss:0.1234	test-logloss:0.172974
# [400]	train-logloss:0.115011	test-logloss:0.169236
# [450]	train-logloss:0.108764	test-logloss:0.167033
# [500]	train-logloss:0.103737	test-logloss:0.165648
# [550]	train-logloss:0.099084	test-logloss:0.164725
# [600]	train-logloss:0.094968	test-logloss:0.164105
# [650]	train-logloss:0.091145	test-logloss:0.163775
# [700]	train-logloss:0.087002	test-logloss:0.163449
# [750]	train-logloss:0.083646	test-logloss:0.163164
# [800]	train-logloss:0.080145	test-logloss:0.162914
# Stopping. Best iteration:
# [825]	train-logloss:0.078331	test-logloss:0.162811
#
# target: 12 bare_ground
# [0]	train-logloss:0.683931	test-logloss:0.684003
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.380897	test-logloss:0.384028
# [100]	train-logloss:0.23674	test-logloss:0.243424
# [150]	train-logloss:0.159232	test-logloss:0.169999
# [200]	train-logloss:0.114917	test-logloss:0.130109
# [250]	train-logloss:0.088635	test-logloss:0.108169
# [300]	train-logloss:0.072328	test-logloss:0.095799
# [350]	train-logloss:0.061548	test-logloss:0.08892
# [400]	train-logloss:0.054135	test-logloss:0.085068
# [450]	train-logloss:0.049032	test-logloss:0.082908
# [500]	train-logloss:0.04522	test-logloss:0.081694
# [550]	train-logloss:0.042019	test-logloss:0.08092
# [600]	train-logloss:0.039133	test-logloss:0.080613
# [650]	train-logloss:0.036442	test-logloss:0.080387
# Stopping. Best iteration:
# [662]	train-logloss:0.035851	test-logloss:0.080353
#
# [0]	train-logloss:0.683959	test-logloss:0.683995
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.381532	test-logloss:0.384015
# [100]	train-logloss:0.237544	test-logloss:0.243028
# [150]	train-logloss:0.159967	test-logloss:0.169142
# [200]	train-logloss:0.115435	test-logloss:0.12858
# [250]	train-logloss:0.088652	test-logloss:0.106029
# [300]	train-logloss:0.072156	test-logloss:0.093067
# [350]	train-logloss:0.061284	test-logloss:0.085434
# [400]	train-logloss:0.054151	test-logloss:0.081173
# [450]	train-logloss:0.048965	test-logloss:0.07873
# [500]	train-logloss:0.045124	test-logloss:0.077303
# [550]	train-logloss:0.04198	test-logloss:0.076535
# [600]	train-logloss:0.039168	test-logloss:0.076057
# [650]	train-logloss:0.036598	test-logloss:0.075755
# [700]	train-logloss:0.034169	test-logloss:0.075629
# Stopping. Best iteration:
# [701]	train-logloss:0.034123	test-logloss:0.075621
#
# [0]	train-logloss:0.683918	test-logloss:0.684011
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.380644	test-logloss:0.384524
# [100]	train-logloss:0.236176	test-logloss:0.243998
# [150]	train-logloss:0.15844	test-logloss:0.1706
# [200]	train-logloss:0.113952	test-logloss:0.130587
# [250]	train-logloss:0.087198	test-logloss:0.108377
# [300]	train-logloss:0.070445	test-logloss:0.096048
# [350]	train-logloss:0.05953	test-logloss:0.089214
# [400]	train-logloss:0.052207	test-logloss:0.085431
# [450]	train-logloss:0.047078	test-logloss:0.083333
# [500]	train-logloss:0.043218	test-logloss:0.082236
# [550]	train-logloss:0.039986	test-logloss:0.08167
# [600]	train-logloss:0.037315	test-logloss:0.081345
# [650]	train-logloss:0.035165	test-logloss:0.081281
# Stopping. Best iteration:
# [655]	train-logloss:0.035021	test-logloss:0.081255
#
# target: 13 blow_down
# [0]	train-logloss:0.683285	test-logloss:0.683301
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359382	test-logloss:0.36007
# [100]	train-logloss:0.205408	test-logloss:0.206627
# [150]	train-logloss:0.123065	test-logloss:0.124754
# [200]	train-logloss:0.07676	test-logloss:0.078885
# [250]	train-logloss:0.050125	test-logloss:0.052669
# [300]	train-logloss:0.034404	test-logloss:0.037611
# [350]	train-logloss:0.024866	test-logloss:0.02896
# [400]	train-logloss:0.018697	test-logloss:0.023967
# [450]	train-logloss:0.014658	test-logloss:0.0212
# [500]	train-logloss:0.011861	test-logloss:0.019651
# [550]	train-logloss:0.009774	test-logloss:0.018829
# [600]	train-logloss:0.008087	test-logloss:0.018407
# [650]	train-logloss:0.006749	test-logloss:0.018228
# [700]	train-logloss:0.005708	test-logloss:0.018159
# Stopping. Best iteration:
# [729]	train-logloss:0.005201	test-logloss:0.018135
#
# [0]	train-logloss:0.683299	test-logloss:0.683289
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.360018	test-logloss:0.359581
# [100]	train-logloss:0.206409	test-logloss:0.205634
# [150]	train-logloss:0.124358	test-logloss:0.123285
# [200]	train-logloss:0.078242	test-logloss:0.076968
# [250]	train-logloss:0.051278	test-logloss:0.050284
# [300]	train-logloss:0.034975	test-logloss:0.034733
# [350]	train-logloss:0.025029	test-logloss:0.025657
# [400]	train-logloss:0.018662	test-logloss:0.020358
# [450]	train-logloss:0.014473	test-logloss:0.017312
# [500]	train-logloss:0.011519	test-logloss:0.015543
# [550]	train-logloss:0.009383	test-logloss:0.014577
# [600]	train-logloss:0.007828	test-logloss:0.014035
# [650]	train-logloss:0.006629	test-logloss:0.01371
# [700]	train-logloss:0.005667	test-logloss:0.01357
# [750]	train-logloss:0.004871	test-logloss:0.013537
# Stopping. Best iteration:
# [765]	train-logloss:0.004649	test-logloss:0.013534
#
# [0]	train-logloss:0.683304	test-logloss:0.683298
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359937	test-logloss:0.359687
# [100]	train-logloss:0.206252	test-logloss:0.205809
# [150]	train-logloss:0.124153	test-logloss:0.12354
# [200]	train-logloss:0.078058	test-logloss:0.077291
# [250]	train-logloss:0.051273	test-logloss:0.05073
# [300]	train-logloss:0.035113	test-logloss:0.035318
# [350]	train-logloss:0.025148	test-logloss:0.026295
# [400]	train-logloss:0.01868	test-logloss:0.021098
# [450]	train-logloss:0.014423	test-logloss:0.018093
# [500]	train-logloss:0.011467	test-logloss:0.016388
# [550]	train-logloss:0.009366	test-logloss:0.015498
# [600]	train-logloss:0.007773	test-logloss:0.015051
# [650]	train-logloss:0.006541	test-logloss:0.014876
# [700]	train-logloss:0.005568	test-logloss:0.014788
# Stopping. Best iteration:
# [699]	train-logloss:0.005585	test-logloss:0.014784
#
# target: 14 agriculture
# [0]	train-logloss:0.687515	test-logloss:0.687944
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.49875	test-logloss:0.515143
# [100]	train-logloss:0.400085	test-logloss:0.42931
# [150]	train-logloss:0.342687	test-logloss:0.383058
# [200]	train-logloss:0.305517	test-logloss:0.356201
# [250]	train-logloss:0.280515	test-logloss:0.34024
# [300]	train-logloss:0.261768	test-logloss:0.330295
# [350]	train-logloss:0.246364	test-logloss:0.323347
# [400]	train-logloss:0.234227	test-logloss:0.319116
# [450]	train-logloss:0.224449	test-logloss:0.31633
# [500]	train-logloss:0.215545	test-logloss:0.31384
# [550]	train-logloss:0.207699	test-logloss:0.312076
# [600]	train-logloss:0.201645	test-logloss:0.310832
# [650]	train-logloss:0.195283	test-logloss:0.309667
# [700]	train-logloss:0.190186	test-logloss:0.30879
# [750]	train-logloss:0.184638	test-logloss:0.307969
# [800]	train-logloss:0.179339	test-logloss:0.307277
# [850]	train-logloss:0.174184	test-logloss:0.306587
# [900]	train-logloss:0.169365	test-logloss:0.306038
# [950]	train-logloss:0.165029	test-logloss:0.305502
# [1000]	train-logloss:0.160769	test-logloss:0.305095
# [1050]	train-logloss:0.156783	test-logloss:0.304688
# [1100]	train-logloss:0.152532	test-logloss:0.304297
# [1150]	train-logloss:0.149221	test-logloss:0.304094
# [1200]	train-logloss:0.145448	test-logloss:0.303977
# [1250]	train-logloss:0.141959	test-logloss:0.303786
# Stopping. Best iteration:
# [1243]	train-logloss:0.142344	test-logloss:0.303784
#
# [0]	train-logloss:0.687677	test-logloss:0.688004
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.500032	test-logloss:0.515443
# [100]	train-logloss:0.401947	test-logloss:0.429335
# [150]	train-logloss:0.344931	test-logloss:0.382917
# [200]	train-logloss:0.307847	test-logloss:0.355806
# [250]	train-logloss:0.283038	test-logloss:0.340119
# [300]	train-logloss:0.264003	test-logloss:0.329729
# [350]	train-logloss:0.249368	test-logloss:0.32317
# [400]	train-logloss:0.236591	test-logloss:0.318166
# [450]	train-logloss:0.226066	test-logloss:0.314795
# [500]	train-logloss:0.216195	test-logloss:0.312045
# [550]	train-logloss:0.20887	test-logloss:0.310215
# [600]	train-logloss:0.202377	test-logloss:0.308771
# [650]	train-logloss:0.195746	test-logloss:0.307533
# [700]	train-logloss:0.190086	test-logloss:0.306473
# [750]	train-logloss:0.18503	test-logloss:0.305627
# [800]	train-logloss:0.180227	test-logloss:0.304982
# [850]	train-logloss:0.175536	test-logloss:0.304337
# [900]	train-logloss:0.171008	test-logloss:0.30374
# [950]	train-logloss:0.166789	test-logloss:0.303288
# [1000]	train-logloss:0.162931	test-logloss:0.302833
# [1050]	train-logloss:0.159202	test-logloss:0.302433
# [1100]	train-logloss:0.155261	test-logloss:0.302169
# [1150]	train-logloss:0.151535	test-logloss:0.301887
# [1200]	train-logloss:0.147857	test-logloss:0.301547
# [1250]	train-logloss:0.144466	test-logloss:0.301282
# [1300]	train-logloss:0.141157	test-logloss:0.301108
# Stopping. Best iteration:
# [1302]	train-logloss:0.140984	test-logloss:0.301078
#
# [0]	train-logloss:0.687548	test-logloss:0.687898
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.500122	test-logloss:0.514062
# [100]	train-logloss:0.402746	test-logloss:0.427492
# [150]	train-logloss:0.346197	test-logloss:0.380542
# [200]	train-logloss:0.309437	test-logloss:0.352909
# [250]	train-logloss:0.284406	test-logloss:0.3361
# [300]	train-logloss:0.265891	test-logloss:0.3253
# [350]	train-logloss:0.25119	test-logloss:0.318015
# [400]	train-logloss:0.238806	test-logloss:0.312852
# [450]	train-logloss:0.227971	test-logloss:0.309074
# [500]	train-logloss:0.219168	test-logloss:0.306383
# [550]	train-logloss:0.211274	test-logloss:0.304397
# [600]	train-logloss:0.204818	test-logloss:0.302939
# [650]	train-logloss:0.199132	test-logloss:0.301898
# [700]	train-logloss:0.193443	test-logloss:0.300733
# [750]	train-logloss:0.188679	test-logloss:0.299914
# [800]	train-logloss:0.183432	test-logloss:0.299114
# [850]	train-logloss:0.178657	test-logloss:0.298411
# [900]	train-logloss:0.173831	test-logloss:0.297694
# [950]	train-logloss:0.169608	test-logloss:0.297081
# [1000]	train-logloss:0.165234	test-logloss:0.296568
# [1050]	train-logloss:0.161252	test-logloss:0.296043
# [1100]	train-logloss:0.157391	test-logloss:0.295658
# [1150]	train-logloss:0.153466	test-logloss:0.295178
# [1200]	train-logloss:0.149725	test-logloss:0.294846
# [1250]	train-logloss:0.146044	test-logloss:0.294429
# [1300]	train-logloss:0.142508	test-logloss:0.294117
# [1350]	train-logloss:0.139059	test-logloss:0.293876
# Stopping. Best iteration:
# [1354]	train-logloss:0.138886	test-logloss:0.293841
#
# target: 15 road
# [0]	train-logloss:0.686873	test-logloss:0.687216
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.477486	test-logloss:0.49195
# [100]	train-logloss:0.371875	test-logloss:0.398478
# [150]	train-logloss:0.311145	test-logloss:0.348474
# [200]	train-logloss:0.274101	test-logloss:0.320734
# [250]	train-logloss:0.250326	test-logloss:0.305042
# [300]	train-logloss:0.233924	test-logloss:0.296151
# [350]	train-logloss:0.221329	test-logloss:0.290437
# [400]	train-logloss:0.211548	test-logloss:0.286985
# [450]	train-logloss:0.203181	test-logloss:0.284785
# [500]	train-logloss:0.194889	test-logloss:0.283077
# [550]	train-logloss:0.187616	test-logloss:0.281921
# [600]	train-logloss:0.181434	test-logloss:0.280928
# [650]	train-logloss:0.175526	test-logloss:0.280179
# [700]	train-logloss:0.170094	test-logloss:0.279664
# [750]	train-logloss:0.165105	test-logloss:0.279252
# [800]	train-logloss:0.160763	test-logloss:0.27892
# [850]	train-logloss:0.156783	test-logloss:0.278646
# [900]	train-logloss:0.153252	test-logloss:0.278408
# [950]	train-logloss:0.149361	test-logloss:0.278275
# Stopping. Best iteration:
# [954]	train-logloss:0.148974	test-logloss:0.278223
#
# [0]	train-logloss:0.686835	test-logloss:0.687217
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.478292	test-logloss:0.492007
# [100]	train-logloss:0.372192	test-logloss:0.397654
# [150]	train-logloss:0.312044	test-logloss:0.3471
# [200]	train-logloss:0.275128	test-logloss:0.318696
# [250]	train-logloss:0.251335	test-logloss:0.302513
# [300]	train-logloss:0.234935	test-logloss:0.292993
# [350]	train-logloss:0.222827	test-logloss:0.287183
# [400]	train-logloss:0.213116	test-logloss:0.283434
# [450]	train-logloss:0.203813	test-logloss:0.280831
# [500]	train-logloss:0.196265	test-logloss:0.279075
# [550]	train-logloss:0.188973	test-logloss:0.277695
# [600]	train-logloss:0.182786	test-logloss:0.27667
# [650]	train-logloss:0.177123	test-logloss:0.275926
# [700]	train-logloss:0.171734	test-logloss:0.275298
# [750]	train-logloss:0.166904	test-logloss:0.274969
# [800]	train-logloss:0.162104	test-logloss:0.274396
# [850]	train-logloss:0.157578	test-logloss:0.274127
# [900]	train-logloss:0.153511	test-logloss:0.273892
# [950]	train-logloss:0.149797	test-logloss:0.273653
# Stopping. Best iteration:
# [974]	train-logloss:0.148093	test-logloss:0.273546
#
# [0]	train-logloss:0.68692	test-logloss:0.687298
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.477068	test-logloss:0.493326
# [100]	train-logloss:0.370688	test-logloss:0.400087
# [150]	train-logloss:0.310453	test-logloss:0.350893
# [200]	train-logloss:0.273881	test-logloss:0.323426
# [250]	train-logloss:0.250104	test-logloss:0.30797
# [300]	train-logloss:0.234013	test-logloss:0.299156
# [350]	train-logloss:0.221776	test-logloss:0.293868
# [400]	train-logloss:0.211792	test-logloss:0.29048
# [450]	train-logloss:0.203835	test-logloss:0.288488
# [500]	train-logloss:0.197268	test-logloss:0.287156
# [550]	train-logloss:0.190667	test-logloss:0.286173
# [600]	train-logloss:0.183679	test-logloss:0.285234
# [650]	train-logloss:0.177338	test-logloss:0.284488
# [700]	train-logloss:0.172032	test-logloss:0.284084
# [750]	train-logloss:0.166816	test-logloss:0.283567
# [800]	train-logloss:0.162142	test-logloss:0.283162
# [850]	train-logloss:0.157813	test-logloss:0.282993
# Stopping. Best iteration:
# [837]	train-logloss:0.158797	test-logloss:0.282987
#
# target: 16 selective_logging
# [0]	train-logloss:0.683522	test-logloss:0.68353
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.36722	test-logloss:0.368145
# [100]	train-logloss:0.216845	test-logloss:0.219017
# [150]	train-logloss:0.136128	test-logloss:0.13997
# [200]	train-logloss:0.090216	test-logloss:0.095983
# [250]	train-logloss:0.063014	test-logloss:0.070952
# [300]	train-logloss:0.046408	test-logloss:0.056633
# [350]	train-logloss:0.03584	test-logloss:0.048465
# [400]	train-logloss:0.02891	test-logloss:0.043729
# [450]	train-logloss:0.024193	test-logloss:0.041038
# [500]	train-logloss:0.021095	test-logloss:0.039516
# [550]	train-logloss:0.018897	test-logloss:0.038695
# [600]	train-logloss:0.017245	test-logloss:0.038201
# [650]	train-logloss:0.015833	test-logloss:0.037951
# [700]	train-logloss:0.014588	test-logloss:0.037789
# Stopping. Best iteration:
# [719]	train-logloss:0.014173	test-logloss:0.037729
#
# [0]	train-logloss:0.68353	test-logloss:0.683529
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367409	test-logloss:0.367961
# [100]	train-logloss:0.217077	test-logloss:0.218664
# [150]	train-logloss:0.136484	test-logloss:0.139495
# [200]	train-logloss:0.090627	test-logloss:0.095484
# [250]	train-logloss:0.06348	test-logloss:0.070382
# [300]	train-logloss:0.046955	test-logloss:0.05593
# [350]	train-logloss:0.036667	test-logloss:0.047549
# [400]	train-logloss:0.029985	test-logloss:0.04273
# [450]	train-logloss:0.025613	test-logloss:0.039959
# [500]	train-logloss:0.022565	test-logloss:0.038372
# [550]	train-logloss:0.020411	test-logloss:0.037493
# [600]	train-logloss:0.018782	test-logloss:0.037
# [650]	train-logloss:0.017311	test-logloss:0.036756
# [700]	train-logloss:0.016066	test-logloss:0.036592
# [750]	train-logloss:0.014832	test-logloss:0.036515
# Stopping. Best iteration:
# [768]	train-logloss:0.014392	test-logloss:0.036496
#
# [0]	train-logloss:0.683517	test-logloss:0.683535
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367332	test-logloss:0.367926
# [100]	train-logloss:0.216698	test-logloss:0.218507
# [150]	train-logloss:0.135875	test-logloss:0.139252
# [200]	train-logloss:0.089858	test-logloss:0.095247
# [250]	train-logloss:0.062706	test-logloss:0.070251
# [300]	train-logloss:0.045999	test-logloss:0.05599
# [350]	train-logloss:0.035603	test-logloss:0.047936
# [400]	train-logloss:0.028958	test-logloss:0.04339
# [450]	train-logloss:0.024599	test-logloss:0.040892
# [500]	train-logloss:0.021679	test-logloss:0.039599
# [550]	train-logloss:0.019446	test-logloss:0.038869
# [600]	train-logloss:0.017765	test-logloss:0.038549
# [650]	train-logloss:0.016396	test-logloss:0.038436
# Stopping. Best iteration:
# [663]	train-logloss:0.016051	test-logloss:0.038427
#
# bestRounds:
# {0: 660, 1: 1072, 2: 718, 3: 730, 4: 819, 5: 725, 6: 895, 7: 741, 8: 578, 9: 980, 10: 891, 11: 825, 12: 655, 13: 699, 14: 1354, 15: 837, 16: 663}

# %%
# xgboost predict




predsDF = pd.DataFrame()
for i in range(0,17):
    print ('predicting feature ' + str(i))
    Y_train = Y_trainAll.ix[:,i]
    #print (Y_train.shape)
    preds, model, br = runXGB(X_train, Y_train, X_test, num_rounds=int(brDict[i]*1.33))
    predsDF[i] = preds

print (predsDF.shape)
# Out:
# predicting feature 0
# predicting feature 1
# predicting feature 2
# predicting feature 3
# predicting feature 4
# predicting feature 5
# predicting feature 6
# predicting feature 7
# predicting feature 8
# predicting feature 9
# predicting feature 10
# predicting feature 11
# predicting feature 12
# predicting feature 13
# predicting feature 14
# predicting feature 15
# predicting feature 16
# (40669, 17)

# %%
i = xgb.importance(model=model)
print (i)

# %%
print (predsDF.head())
print (X_train_id[0:5])

# %%
# predsDF to prediction file

def mapf (arr):
    res = ''
    for i in range(0,17):
        if arr[i] > 0.5:
            res += inv_label_map[i] + ' '
    res = res.rstrip()
    return res

print(predsDF.shape)

textResults = []

for i, row in predsDF.iterrows():
    #print (i)
    #print (list(row))
    textResults.append ( mapf( list (row)))
    
print (textResults[0:5])

res = pd.DataFrame()
res['image_name'] = X_test_id
res['tags'] = textResults

print (res.head())

res.to_csv('SUB_25_0.01eta.csv', index=False)

# %%
# save RAW
