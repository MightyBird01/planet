# %%
from skimage import io
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os
import glob
import xgboost as xgb
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
import scipy
from scipy import stats

# %matplotlib inline

path1 = '/home/gs/DataScientist/planet'
trainPath = '/train-tif'
testPath = '/test-tif'

VERBOSE_INTERVAL = 2500

NUM_BINS = 64
MAX_PIX_VAL = 65535
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# definitions

def getImageData (filePath):
    stats = []
    try:
        img = io.imread(filePath)
        r, g, b, nir = img[:, :, 0], img[:, :, 1], img[:, :, 2], img[:, :, 3]
        if not 0 in (nir+r):
            n = (nir-r) / (nir+r)
        else:
            n = np.zeros(256)
                
        hr, bins = np.histogram(r,NUM_BINS,[0, MAX_PIX_VAL])
        hg, bins = np.histogram(g,NUM_BINS,[0, MAX_PIX_VAL])
        hb, bins = np.histogram(b,NUM_BINS,[0, MAX_PIX_VAL])
        hnir, bins = np.histogram(nir,NUM_BINS,[0, MAX_PIX_VAL])
        ndvi, bins = np.histogram(n,NUM_BINS,[-1, +1])

        # stats
        stats.append( np.mean(r) )
        stats.append( np.mean(g) )
        stats.append( np.mean(b) )
        stats.append( np.mean(nir) )
        stats.append( np.std(r) )
        stats.append( np.std(g) )
        stats.append( np.std(b) )
        stats.append( np.std(nir) )
        stats.append( np.min(r) )
        stats.append( np.min(g) )
        stats.append( np.min(b) )
        stats.append( np.min(nir) )
        stats.append( np.max(r) )
        stats.append( np.max(g) )
        stats.append( np.max(b) )
        stats.append( np.max(nir) )

        stats.append( scipy.stats.kurtosis(r.ravel()) )
        stats.append( scipy.stats.kurtosis(g.ravel()) )
        stats.append( scipy.stats.kurtosis(b.ravel()) )
        stats.append( scipy.stats.kurtosis(nir.ravel()) )
        stats.append( scipy.stats.skew(r.ravel()) )
        stats.append( scipy.stats.skew(g.ravel()) )
        stats.append( scipy.stats.skew(b.ravel()) )
        stats.append( scipy.stats.skew(nir.ravel()) )
        
        # to array
        stats = np.array(stats)
        
    except Exception as  e:
        print ('{}  error reading file {}'.format(e, filePath))
        hr = np.zeros(NUM_BINS)
        hg = np.zeros(NUM_BINS)
        hb = np.zeros(NUM_BINS)
        hnir = np.zeros(NUM_BINS)
        ndvi = np.zeros(NUM_BINS)
        stats = np.zeros(24)

    r = np.concatenate((hr, hg, hb, hnir, ndvi, stats), axis = 0)
    return r

def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=2000):
    br = 0
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.01
    param['max_depth'] = 8
    param['silent'] = 1
    param['eval_metric'] = "logloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.8
    param['colsample_bytree'] = 0.8
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20, verbose_eval = 50)
        br = model.best_iteration
        #print ('best iteration for DICT: {}'.format(br))
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds, verbose_eval = 50)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model, br

# %%
print (getImageData('/home/gs/DataScientist/planet/train-tif/train_1.tif'))

# %%
# read Y_train

print ('read train y...')

try:
    Y_train = pd.read_csv(path1+'/train.csv')
except:
    path1 = '/home/ec2-user/DataScientist/planet'
    Y_train = pd.read_csv(path1+'/train.csv')

print ('Y_train lines read: {}'.format(len(Y_train)))

flatten = lambda l: [item for sublist in l for item in sublist]
labels = list(set(flatten([l.split(' ') for l in Y_train['tags'].values])))
label_map = {l: i for i, l in enumerate(labels)}
inv_label_map = {i: l for l, i in label_map.items()}
#print(label_map)
#print
#print(inv_label_map)

Y_trainDict = {}
for i, row in Y_train.iterrows():
    name = row['image_name']
    tags = row['tags']
    targets = np.zeros(17)
    for t in tags.split(' '):
        targets[label_map[t]] = 1 
    Y_trainDict[name] = targets

#print (Y_trainDict['train_0'])
#print (Y_trainDict['train_1'])
#print (Y_trainDict['train_2'])


# read train images

X_train = [] # arrays

Y_trainAll = []
X_train_id = []
lines = 0

print('Read train images')
path = os.path.join(path1+trainPath, '*.tif')
print (path)
files = glob.glob(path)
for fl in files:
    lines += 1
    if lines % VERBOSE_INTERVAL == 0:
        print ('  files read: {}'.format(lines))
    flbase = os.path.basename(fl)
    r = getImageData(fl)
    X_train.append(r)
    name = flbase.replace('.tif', '')
    X_train_id.append(name)
    Y_trainAll.append(Y_trainDict[name])


Y_trainAll = pd.DataFrame(Y_trainAll)

X_train = pd.DataFrame(X_train)
print ('X_train shape   : {}'.format(X_train.shape))
print ('Y_trainAll shape: {}'.format(Y_trainAll.shape))


X_test = [] # arrays
X_test_id = []
lines = 0 

print('Read test images')
path = os.path.join(path1+testPath, '*.tif')
print (path)
files = glob.glob(path)
for fl in files:
    lines += 1
    if lines % VERBOSE_INTERVAL == 0:
        print ('  files read: {}'.format(lines))
    flbase = os.path.basename(fl)
    r = getImageData(fl)
    X_test.append(r)
    name = flbase.replace('.tif', '')
    X_test_id.append(name)

X_test = pd.DataFrame(X_test)
print (X_test.shape)
# Out:
# read train y...
# Y_train lines read: 40479
# Read train images
# /home/gs/DataScientist/planet/train-tif/*.tif
#   files read: 2500
#   files read: 5000
# /usr/local/lib/python2.7/dist-packages/skimage/external/tifffile/tifffile.py:2546: UserWarning: unpack: string size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
#   files read: 7500
#   files read: 10000
#   files read: 12500
#   files read: 15000
#   files read: 17500
#   files read: 20000
# invalid offset  error reading file /home/gs/DataScientist/planet/train-tif/train_28173.tif
#   files read: 22500
# invalid offset  error reading file /home/gs/DataScientist/planet/train-tif/train_18772.tif
#   files read: 25000
#   files read: 27500
#   files read: 30000
#   files read: 32500
#   files read: 35000
# invalid TIFF file  error reading file /home/gs/DataScientist/planet/train-tif/train_5023.tif
#   files read: 37500
#   files read: 40000
# X_train shape   : (40479, 344)
# Y_trainAll shape: (40479, 17)
# Read test images
# /home/gs/DataScientist/planet/test-tif/*.tif
#   files read: 2500
#   files read: 5000
#   files read: 7500
#   files read: 10000
#   files read: 12500
#   files read: 15000
#   files read: 17500
#   files read: 20000
#   files read: 22500
# too many indices for array  error reading file /home/gs/DataScientist/planet/test-tif/test_17393.tif
#   files read: 25000
#   files read: 27500
#   files read: 30000
#   files read: 32500
#   files read: 35000
#   files read: 37500
#   files read: 40000
# (40669, 344)

# %%
# save data frames for later use

# Y_trainAll
# X_train
# X_test

import pickle
pickle.dump( Y_trainAll, open( "SAVE_yTrainAll.p", "wb" ) )
pickle.dump( X_train, open( "SAVE_xTrain.p", "wb" ) )
pickle.dump( X_test, open( "SAVE_xTest.p", "wb" ) )
pickle.dump( Y_trainDict, open( "SAVE_yTrainDict.p", "wb" ) )
pickle.dump( label_map, open( "SAVE_labelMap.p", "wb" ) )
pickle.dump( inv_label_map, open( "SAVE_invLabelMap.p", "wb" ) )

# %%
# load data
import pickle
Y_trainAll = pickle.load( open( "SAVE_yTrainAll.p", "rb" ) )
X_train = pickle.load( open( "SAVE_xTrain.p", "rb" ) )
X_test = pickle.load( open( "SAVE_xTest.p", "rb" ) )
Y_trainDict = pickle.load( open( "SAVE_yTrainDict.p", "rb" ) )
label_map = pickle.load( open( "SAVE_labelMap.p", "rb" ) )
inv_label_map = pickle.load( open( "SAVE_invLabelMap.p", "rb" ) )

# %%
# xgb cross validation

# save number of rounds!
brDict = {}

for i in range(0,17):
    print ('target: {} {}'.format(i, inv_label_map[i]))
    Y_train = Y_trainAll.ix[:,i]

    kf = model_selection.KFold(n_splits=3, shuffle=True, random_state=2016)
    for dev_index, val_index in kf.split(range(X_train.shape[0])):
        dev_X, val_X = X_train.iloc[dev_index], X_train.iloc[val_index]
        dev_y, val_y = Y_train.iloc[dev_index], Y_train.iloc[val_index]
        preds, model, br = runXGB(dev_X, dev_y, val_X, val_y)
        brDict[i] = br

print ('bestRounds:')
print (brDict)
# Out:
# target: 0 slash_burn
# [0]	train-logloss:0.683392	test-logloss:0.683414
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.363071	test-logloss:0.364071
# [100]	train-logloss:0.210861	test-logloss:0.212984
# [150]	train-logloss:0.129377	test-logloss:0.132788
# [200]	train-logloss:0.083144	test-logloss:0.088174
# [250]	train-logloss:0.055791	test-logloss:0.062815
# [300]	train-logloss:0.039081	test-logloss:0.048299
# [350]	train-logloss:0.028395	test-logloss:0.039935
# [400]	train-logloss:0.021515	test-logloss:0.035241
# [450]	train-logloss:0.016828	test-logloss:0.03263
# [500]	train-logloss:0.013608	test-logloss:0.031289
# [550]	train-logloss:0.011333	test-logloss:0.030652
# [600]	train-logloss:0.00961	test-logloss:0.030437
# Stopping. Best iteration:
# [620]	train-logloss:0.009053	test-logloss:0.030397
#
# [0]	train-logloss:0.68344	test-logloss:0.683397
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.364518	test-logloss:0.36286
# [100]	train-logloss:0.21301	test-logloss:0.210672
# [150]	train-logloss:0.131765	test-logloss:0.129388
# [200]	train-logloss:0.085447	test-logloss:0.083704
# [250]	train-logloss:0.057855	test-logloss:0.057281
# [300]	train-logloss:0.040833	test-logloss:0.041808
# [350]	train-logloss:0.029947	test-logloss:0.03275
# [400]	train-logloss:0.022986	test-logloss:0.027362
# [450]	train-logloss:0.018225	test-logloss:0.024166
# [500]	train-logloss:0.014931	test-logloss:0.022239
# [550]	train-logloss:0.012688	test-logloss:0.021118
# [600]	train-logloss:0.010997	test-logloss:0.020408
# [650]	train-logloss:0.00972	test-logloss:0.020044
# [700]	train-logloss:0.008651	test-logloss:0.019797
# [750]	train-logloss:0.007803	test-logloss:0.019682
# [800]	train-logloss:0.007022	test-logloss:0.019621
# Stopping. Best iteration:
# [802]	train-logloss:0.006991	test-logloss:0.019616
#
# [0]	train-logloss:0.683392	test-logloss:0.683413
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.363113	test-logloss:0.364
# [100]	train-logloss:0.211038	test-logloss:0.212922
# [150]	train-logloss:0.129599	test-logloss:0.132681
# [200]	train-logloss:0.083363	test-logloss:0.088022
# [250]	train-logloss:0.056031	test-logloss:0.062563
# [300]	train-logloss:0.039389	test-logloss:0.047986
# [350]	train-logloss:0.028852	test-logloss:0.03963
# [400]	train-logloss:0.02197	test-logloss:0.034905
# [450]	train-logloss:0.017257	test-logloss:0.032226
# [500]	train-logloss:0.014029	test-logloss:0.03074
# [550]	train-logloss:0.011748	test-logloss:0.029952
# [600]	train-logloss:0.010031	test-logloss:0.029566
# [650]	train-logloss:0.008736	test-logloss:0.029373
# Stopping. Best iteration:
# [660]	train-logloss:0.008533	test-logloss:0.029354
#
# target: 1 clear
# [0]	train-logloss:0.685999	test-logloss:0.686295
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.445692	test-logloss:0.458227
# [100]	train-logloss:0.325943	test-logloss:0.348183
# [150]	train-logloss:0.257051	test-logloss:0.287697
# [200]	train-logloss:0.213341	test-logloss:0.252328
# [250]	train-logloss:0.18588	test-logloss:0.232234
# [300]	train-logloss:0.166714	test-logloss:0.21988
# [350]	train-logloss:0.152317	test-logloss:0.212019
# [400]	train-logloss:0.141169	test-logloss:0.207006
# [450]	train-logloss:0.132125	test-logloss:0.203737
# [500]	train-logloss:0.124895	test-logloss:0.201455
# [550]	train-logloss:0.118628	test-logloss:0.19986
# [600]	train-logloss:0.113449	test-logloss:0.198572
# [650]	train-logloss:0.108776	test-logloss:0.197648
# [700]	train-logloss:0.104348	test-logloss:0.196895
# [750]	train-logloss:0.100212	test-logloss:0.196184
# [800]	train-logloss:0.096408	test-logloss:0.195742
# [850]	train-logloss:0.092934	test-logloss:0.195369
# [900]	train-logloss:0.089826	test-logloss:0.195026
# [950]	train-logloss:0.087009	test-logloss:0.1948
# [1000]	train-logloss:0.083902	test-logloss:0.194546
# [1050]	train-logloss:0.081193	test-logloss:0.194395
# [1100]	train-logloss:0.078568	test-logloss:0.194348
# [1150]	train-logloss:0.076119	test-logloss:0.194284
# Stopping. Best iteration:
# [1141]	train-logloss:0.076485	test-logloss:0.194235
#
# [0]	train-logloss:0.685962	test-logloss:0.686152
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.447214	test-logloss:0.45629
# [100]	train-logloss:0.327333	test-logloss:0.344652
# [150]	train-logloss:0.258091	test-logloss:0.28375
# [200]	train-logloss:0.214782	test-logloss:0.248709
# [250]	train-logloss:0.18667	test-logloss:0.227973
# [300]	train-logloss:0.167679	test-logloss:0.215982
# [350]	train-logloss:0.153584	test-logloss:0.208238
# [400]	train-logloss:0.142688	test-logloss:0.20347
# [450]	train-logloss:0.134655	test-logloss:0.20058
# [500]	train-logloss:0.127418	test-logloss:0.19828
# [550]	train-logloss:0.121547	test-logloss:0.196589
# [600]	train-logloss:0.116425	test-logloss:0.195408
# [650]	train-logloss:0.111514	test-logloss:0.194366
# [700]	train-logloss:0.107285	test-logloss:0.193525
# [750]	train-logloss:0.103261	test-logloss:0.192998
# [800]	train-logloss:0.09936	test-logloss:0.192398
# [850]	train-logloss:0.095636	test-logloss:0.191936
# [900]	train-logloss:0.092467	test-logloss:0.191593
# [950]	train-logloss:0.089157	test-logloss:0.191308
# [1000]	train-logloss:0.085948	test-logloss:0.191013
# [1050]	train-logloss:0.083144	test-logloss:0.190869
# [1100]	train-logloss:0.080018	test-logloss:0.190705
# [1150]	train-logloss:0.077568	test-logloss:0.190625
# [1200]	train-logloss:0.07505	test-logloss:0.190574
# [1250]	train-logloss:0.072864	test-logloss:0.190486
# Stopping. Best iteration:
# [1277]	train-logloss:0.071577	test-logloss:0.190419
#
# [0]	train-logloss:0.685873	test-logloss:0.686248
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.445508	test-logloss:0.460653
# [100]	train-logloss:0.324021	test-logloss:0.351022
# [150]	train-logloss:0.254348	test-logloss:0.29123
# [200]	train-logloss:0.210524	test-logloss:0.256732
# [250]	train-logloss:0.182535	test-logloss:0.236841
# [300]	train-logloss:0.163559	test-logloss:0.225404
# [350]	train-logloss:0.149839	test-logloss:0.218315
# [400]	train-logloss:0.138549	test-logloss:0.213418
# [450]	train-logloss:0.129661	test-logloss:0.210339
# [500]	train-logloss:0.122503	test-logloss:0.208268
# [550]	train-logloss:0.116551	test-logloss:0.206772
# [600]	train-logloss:0.111556	test-logloss:0.205596
# [650]	train-logloss:0.107032	test-logloss:0.20464
# [700]	train-logloss:0.102858	test-logloss:0.203826
# [750]	train-logloss:0.098793	test-logloss:0.203276
# [800]	train-logloss:0.094732	test-logloss:0.202736
# [850]	train-logloss:0.091207	test-logloss:0.202267
# [900]	train-logloss:0.087812	test-logloss:0.201891
# [950]	train-logloss:0.08498	test-logloss:0.201721
# [1000]	train-logloss:0.082082	test-logloss:0.201568
# [1050]	train-logloss:0.079277	test-logloss:0.201426
# [1100]	train-logloss:0.076654	test-logloss:0.201333
# [1150]	train-logloss:0.073938	test-logloss:0.201305
# Stopping. Best iteration:
# [1143]	train-logloss:0.074283	test-logloss:0.201298
#
# target: 2 blooming
# [0]	train-logloss:0.683545	test-logloss:0.683522
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367994	test-logloss:0.367482
# [100]	train-logloss:0.218242	test-logloss:0.217841
# [150]	train-logloss:0.138111	test-logloss:0.138373
# [200]	train-logloss:0.09248	test-logloss:0.093942
# [250]	train-logloss:0.06527	test-logloss:0.068462
# [300]	train-logloss:0.048486	test-logloss:0.053639
# [350]	train-logloss:0.037748	test-logloss:0.04494
# [400]	train-logloss:0.030912	test-logloss:0.039894
# [450]	train-logloss:0.0262	test-logloss:0.036903
# [500]	train-logloss:0.022949	test-logloss:0.035124
# [550]	train-logloss:0.020574	test-logloss:0.034137
# [600]	train-logloss:0.018757	test-logloss:0.033524
# [650]	train-logloss:0.017397	test-logloss:0.033208
# [700]	train-logloss:0.016156	test-logloss:0.033043
# [750]	train-logloss:0.014945	test-logloss:0.032972
# Stopping. Best iteration:
# [745]	train-logloss:0.01506	test-logloss:0.032958
#
# [0]	train-logloss:0.68351	test-logloss:0.683535
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367039	test-logloss:0.368222
# [100]	train-logloss:0.216822	test-logloss:0.219367
# [150]	train-logloss:0.136451	test-logloss:0.140645
# [200]	train-logloss:0.090965	test-logloss:0.097012
# [250]	train-logloss:0.064071	test-logloss:0.07235
# [300]	train-logloss:0.047468	test-logloss:0.058289
# [350]	train-logloss:0.036966	test-logloss:0.050255
# [400]	train-logloss:0.030182	test-logloss:0.04576
# [450]	train-logloss:0.025612	test-logloss:0.043358
# [500]	train-logloss:0.022453	test-logloss:0.042058
# [550]	train-logloss:0.02008	test-logloss:0.041386
# [600]	train-logloss:0.018264	test-logloss:0.041137
# [650]	train-logloss:0.016844	test-logloss:0.041047
# Stopping. Best iteration:
# [656]	train-logloss:0.016668	test-logloss:0.041022
#
# [0]	train-logloss:0.683519	test-logloss:0.683518
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.36741	test-logloss:0.367746
# [100]	train-logloss:0.217275	test-logloss:0.218467
# [150]	train-logloss:0.136717	test-logloss:0.139336
# [200]	train-logloss:0.090649	test-logloss:0.095336
# [250]	train-logloss:0.063446	test-logloss:0.070396
# [300]	train-logloss:0.046685	test-logloss:0.056183
# [350]	train-logloss:0.036183	test-logloss:0.048179
# [400]	train-logloss:0.029276	test-logloss:0.043687
# [450]	train-logloss:0.024757	test-logloss:0.041252
# [500]	train-logloss:0.021752	test-logloss:0.039896
# [550]	train-logloss:0.019432	test-logloss:0.039141
# [600]	train-logloss:0.017639	test-logloss:0.038793
# [650]	train-logloss:0.01614	test-logloss:0.038613
# [700]	train-logloss:0.014881	test-logloss:0.038533
# Stopping. Best iteration:
# [692]	train-logloss:0.0151	test-logloss:0.038531
#
# target: 3 primary
# [0]	train-logloss:0.684221	test-logloss:0.684443
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.389949	test-logloss:0.39942
# [100]	train-logloss:0.247029	test-logloss:0.264466
# [150]	train-logloss:0.168266	test-logloss:0.192856
# [200]	train-logloss:0.122008	test-logloss:0.152684
# [250]	train-logloss:0.093566	test-logloss:0.129696
# [300]	train-logloss:0.075851	test-logloss:0.116432
# [350]	train-logloss:0.064466	test-logloss:0.109094
# [400]	train-logloss:0.056674	test-logloss:0.104943
# [450]	train-logloss:0.051123	test-logloss:0.10264
# [500]	train-logloss:0.047177	test-logloss:0.101419
# [550]	train-logloss:0.044285	test-logloss:0.10082
# [600]	train-logloss:0.041871	test-logloss:0.100504
# [650]	train-logloss:0.039843	test-logloss:0.100396
# Stopping. Best iteration:
# [646]	train-logloss:0.040005	test-logloss:0.10035
#
# [0]	train-logloss:0.684254	test-logloss:0.684443
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.39068	test-logloss:0.39845
# [100]	train-logloss:0.248185	test-logloss:0.262488
# [150]	train-logloss:0.169833	test-logloss:0.190052
# [200]	train-logloss:0.12365	test-logloss:0.149494
# [250]	train-logloss:0.095113	test-logloss:0.126145
# [300]	train-logloss:0.077219	test-logloss:0.11258
# [350]	train-logloss:0.065598	test-logloss:0.104782
# [400]	train-logloss:0.057681	test-logloss:0.100258
# [450]	train-logloss:0.052332	test-logloss:0.097685
# [500]	train-logloss:0.04855	test-logloss:0.096358
# [550]	train-logloss:0.04561	test-logloss:0.095557
# [600]	train-logloss:0.043379	test-logloss:0.09516
# [650]	train-logloss:0.041316	test-logloss:0.095059
# [700]	train-logloss:0.039421	test-logloss:0.094979
# Stopping. Best iteration:
# [703]	train-logloss:0.039333	test-logloss:0.094965
#
# [0]	train-logloss:0.684258	test-logloss:0.68447
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.390666	test-logloss:0.3989
# [100]	train-logloss:0.248065	test-logloss:0.263281
# [150]	train-logloss:0.169681	test-logloss:0.191028
# [200]	train-logloss:0.123387	test-logloss:0.150371
# [250]	train-logloss:0.094497	test-logloss:0.126927
# [300]	train-logloss:0.076481	test-logloss:0.113277
# [350]	train-logloss:0.064845	test-logloss:0.105429
# [400]	train-logloss:0.057247	test-logloss:0.100991
# [450]	train-logloss:0.051806	test-logloss:0.098355
# [500]	train-logloss:0.048037	test-logloss:0.096832
# [550]	train-logloss:0.045074	test-logloss:0.095985
# [600]	train-logloss:0.042916	test-logloss:0.095513
# [650]	train-logloss:0.040764	test-logloss:0.095223
# [700]	train-logloss:0.038914	test-logloss:0.095037
# [750]	train-logloss:0.037212	test-logloss:0.094983
# Stopping. Best iteration:
# [730]	train-logloss:0.037896	test-logloss:0.09494
#
# target: 4 cloudy
# [0]	train-logloss:0.68393	test-logloss:0.684128
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.379075	test-logloss:0.387005
# [100]	train-logloss:0.231129	test-logloss:0.245178
# [150]	train-logloss:0.149744	test-logloss:0.169259
# [200]	train-logloss:0.10207	test-logloss:0.126249
# [250]	train-logloss:0.072777	test-logloss:0.101444
# [300]	train-logloss:0.054391	test-logloss:0.086921
# [350]	train-logloss:0.042511	test-logloss:0.0783
# [400]	train-logloss:0.034713	test-logloss:0.073268
# [450]	train-logloss:0.029301	test-logloss:0.070324
# [500]	train-logloss:0.025503	test-logloss:0.068805
# [550]	train-logloss:0.022764	test-logloss:0.067934
# [600]	train-logloss:0.020733	test-logloss:0.067547
# [650]	train-logloss:0.019117	test-logloss:0.067465
# Stopping. Best iteration:
# [635]	train-logloss:0.019565	test-logloss:0.067435
#
# [0]	train-logloss:0.683908	test-logloss:0.684117
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.379236	test-logloss:0.386556
# [100]	train-logloss:0.231377	test-logloss:0.244355
# [150]	train-logloss:0.150486	test-logloss:0.16803
# [200]	train-logloss:0.103079	test-logloss:0.12469
# [250]	train-logloss:0.073991	test-logloss:0.099171
# [300]	train-logloss:0.055663	test-logloss:0.083995
# [350]	train-logloss:0.043878	test-logloss:0.074964
# [400]	train-logloss:0.035934	test-logloss:0.069483
# [450]	train-logloss:0.030542	test-logloss:0.066193
# [500]	train-logloss:0.026678	test-logloss:0.064191
# [550]	train-logloss:0.024	test-logloss:0.063023
# [600]	train-logloss:0.022154	test-logloss:0.062344
# [650]	train-logloss:0.020585	test-logloss:0.061836
# [700]	train-logloss:0.019256	test-logloss:0.061469
# [750]	train-logloss:0.018071	test-logloss:0.061188
# [800]	train-logloss:0.017025	test-logloss:0.061071
# [850]	train-logloss:0.015999	test-logloss:0.060949
# [900]	train-logloss:0.015144	test-logloss:0.060873
# Stopping. Best iteration:
# [900]	train-logloss:0.015144	test-logloss:0.060873
#
# [0]	train-logloss:0.683923	test-logloss:0.684084
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.37969	test-logloss:0.386371
# [100]	train-logloss:0.23217	test-logloss:0.243962
# [150]	train-logloss:0.151142	test-logloss:0.167404
# [200]	train-logloss:0.103391	test-logloss:0.123713
# [250]	train-logloss:0.074086	test-logloss:0.097977
# [300]	train-logloss:0.055688	test-logloss:0.082752
# [350]	train-logloss:0.043978	test-logloss:0.073662
# [400]	train-logloss:0.036165	test-logloss:0.068151
# [450]	train-logloss:0.030744	test-logloss:0.064777
# [500]	train-logloss:0.027015	test-logloss:0.062708
# [550]	train-logloss:0.024249	test-logloss:0.06141
# [600]	train-logloss:0.022357	test-logloss:0.060578
# [650]	train-logloss:0.020796	test-logloss:0.060076
# [700]	train-logloss:0.019592	test-logloss:0.059779
# [750]	train-logloss:0.018431	test-logloss:0.059522
# [800]	train-logloss:0.017378	test-logloss:0.059413
# [850]	train-logloss:0.016408	test-logloss:0.059356
# [900]	train-logloss:0.015515	test-logloss:0.059338
# Stopping. Best iteration:
# [888]	train-logloss:0.015723	test-logloss:0.059314
#
# target: 5 conventional_mine
# [0]	train-logloss:0.683286	test-logloss:0.683305
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359275	test-logloss:0.360141
# [100]	train-logloss:0.205029	test-logloss:0.206685
# [150]	train-logloss:0.1222	test-logloss:0.124665
# [200]	train-logloss:0.074995	test-logloss:0.078448
# [250]	train-logloss:0.047227	test-logloss:0.051677
# [300]	train-logloss:0.030484	test-logloss:0.03594
# [350]	train-logloss:0.020246	test-logloss:0.026635
# [400]	train-logloss:0.013852	test-logloss:0.021209
# [450]	train-logloss:0.009822	test-logloss:0.018035
# [500]	train-logloss:0.007233	test-logloss:0.016186
# [550]	train-logloss:0.005523	test-logloss:0.01519
# [600]	train-logloss:0.004334	test-logloss:0.014617
# [650]	train-logloss:0.003507	test-logloss:0.014295
# [700]	train-logloss:0.002896	test-logloss:0.014106
# [750]	train-logloss:0.002445	test-logloss:0.014028
# [800]	train-logloss:0.002087	test-logloss:0.014006
# Stopping. Best iteration:
# [813]	train-logloss:0.002011	test-logloss:0.01399
#
# [0]	train-logloss:0.683314	test-logloss:0.683295
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.360256	test-logloss:0.359483
# [100]	train-logloss:0.206247	test-logloss:0.205304
# [150]	train-logloss:0.123282	test-logloss:0.122636
# [200]	train-logloss:0.075917	test-logloss:0.075877
# [250]	train-logloss:0.047961	test-logloss:0.048643
# [300]	train-logloss:0.031112	test-logloss:0.032614
# [350]	train-logloss:0.020792	test-logloss:0.023095
# [400]	train-logloss:0.014344	test-logloss:0.017477
# [450]	train-logloss:0.01025	test-logloss:0.014135
# [500]	train-logloss:0.007596	test-logloss:0.012181
# [550]	train-logloss:0.005819	test-logloss:0.011048
# [600]	train-logloss:0.004608	test-logloss:0.010412
# [650]	train-logloss:0.003746	test-logloss:0.010061
# [700]	train-logloss:0.003103	test-logloss:0.009824
# [750]	train-logloss:0.002627	test-logloss:0.009727
# Stopping. Best iteration:
# [764]	train-logloss:0.002516	test-logloss:0.0097
#
# [0]	train-logloss:0.683295	test-logloss:0.683294
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359866	test-logloss:0.359835
# [100]	train-logloss:0.205971	test-logloss:0.206008
# [150]	train-logloss:0.123055	test-logloss:0.123552
# [200]	train-logloss:0.075676	test-logloss:0.076986
# [250]	train-logloss:0.047754	test-logloss:0.049865
# [300]	train-logloss:0.030987	test-logloss:0.03395
# [350]	train-logloss:0.020688	test-logloss:0.024532
# [400]	train-logloss:0.014262	test-logloss:0.018952
# [450]	train-logloss:0.01018	test-logloss:0.015679
# [500]	train-logloss:0.007548	test-logloss:0.01378
# [550]	train-logloss:0.005771	test-logloss:0.012703
# [600]	train-logloss:0.004547	test-logloss:0.012129
# [650]	train-logloss:0.00369	test-logloss:0.011824
# [700]	train-logloss:0.003051	test-logloss:0.011718
# Stopping. Best iteration:
# [725]	train-logloss:0.002794	test-logloss:0.011679
#
# target: 6 water
# [0]	train-logloss:0.686489	test-logloss:0.686818
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.464395	test-logloss:0.478491
# [100]	train-logloss:0.35513	test-logloss:0.38112
# [150]	train-logloss:0.293343	test-logloss:0.330306
# [200]	train-logloss:0.255225	test-logloss:0.302352
# [250]	train-logloss:0.229569	test-logloss:0.286491
# [300]	train-logloss:0.212322	test-logloss:0.277683
# [350]	train-logloss:0.199027	test-logloss:0.272472
# [400]	train-logloss:0.188658	test-logloss:0.269343
# [450]	train-logloss:0.180845	test-logloss:0.267411
# [500]	train-logloss:0.173545	test-logloss:0.265861
# [550]	train-logloss:0.167524	test-logloss:0.264887
# [600]	train-logloss:0.161676	test-logloss:0.264173
# [650]	train-logloss:0.157079	test-logloss:0.263765
# [700]	train-logloss:0.152679	test-logloss:0.263413
# [750]	train-logloss:0.148876	test-logloss:0.263161
# Stopping. Best iteration:
# [778]	train-logloss:0.146401	test-logloss:0.262969
#
# [0]	train-logloss:0.686616	test-logloss:0.686796
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.465371	test-logloss:0.476432
# [100]	train-logloss:0.35588	test-logloss:0.377255
# [150]	train-logloss:0.293986	test-logloss:0.325428
# [200]	train-logloss:0.255562	test-logloss:0.297381
# [250]	train-logloss:0.230251	test-logloss:0.281654
# [300]	train-logloss:0.212447	test-logloss:0.272547
# [350]	train-logloss:0.199125	test-logloss:0.267131
# [400]	train-logloss:0.188825	test-logloss:0.263932
# [450]	train-logloss:0.180592	test-logloss:0.262074
# [500]	train-logloss:0.173135	test-logloss:0.260745
# [550]	train-logloss:0.167172	test-logloss:0.25972
# [600]	train-logloss:0.162047	test-logloss:0.259257
# [650]	train-logloss:0.157026	test-logloss:0.258708
# [700]	train-logloss:0.152795	test-logloss:0.258327
# [750]	train-logloss:0.148483	test-logloss:0.258003
# [800]	train-logloss:0.144251	test-logloss:0.257834
# [850]	train-logloss:0.140267	test-logloss:0.2576
# Stopping. Best iteration:
# [877]	train-logloss:0.138577	test-logloss:0.25746
#
# [0]	train-logloss:0.686515	test-logloss:0.686814
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.464471	test-logloss:0.47987
# [100]	train-logloss:0.354606	test-logloss:0.38284
# [150]	train-logloss:0.292526	test-logloss:0.332473
# [200]	train-logloss:0.253836	test-logloss:0.304634
# [250]	train-logloss:0.227917	test-logloss:0.288938
# [300]	train-logloss:0.209823	test-logloss:0.280095
# [350]	train-logloss:0.195885	test-logloss:0.274472
# [400]	train-logloss:0.185513	test-logloss:0.271145
# [450]	train-logloss:0.177235	test-logloss:0.26911
# [500]	train-logloss:0.170534	test-logloss:0.267764
# [550]	train-logloss:0.165112	test-logloss:0.266855
# [600]	train-logloss:0.158939	test-logloss:0.265973
# [650]	train-logloss:0.154509	test-logloss:0.265521
# [700]	train-logloss:0.150533	test-logloss:0.265199
# [750]	train-logloss:0.145872	test-logloss:0.264885
# [800]	train-logloss:0.142467	test-logloss:0.264637
# [850]	train-logloss:0.138937	test-logloss:0.264441
# [900]	train-logloss:0.13524	test-logloss:0.264262
# [950]	train-logloss:0.131753	test-logloss:0.264107
# [1000]	train-logloss:0.128357	test-logloss:0.263964
# [1050]	train-logloss:0.12496	test-logloss:0.263884
# [1100]	train-logloss:0.121931	test-logloss:0.2638
# [1150]	train-logloss:0.11873	test-logloss:0.263667
# Stopping. Best iteration:
# [1150]	train-logloss:0.11873	test-logloss:0.263667
#
# target: 7 haze
# [0]	train-logloss:0.684502	test-logloss:0.684723
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.397421	test-logloss:0.408556
# [100]	train-logloss:0.257999	test-logloss:0.277724
# [150]	train-logloss:0.181475	test-logloss:0.208336
# [200]	train-logloss:0.13655	test-logloss:0.169675
# [250]	train-logloss:0.109011	test-logloss:0.147495
# [300]	train-logloss:0.091526	test-logloss:0.134292
# [350]	train-logloss:0.08009	test-logloss:0.12681
# [400]	train-logloss:0.072264	test-logloss:0.122472
# [450]	train-logloss:0.066462	test-logloss:0.119977
# [500]	train-logloss:0.062117	test-logloss:0.118623
# [550]	train-logloss:0.058696	test-logloss:0.11788
# [600]	train-logloss:0.055785	test-logloss:0.117433
# [650]	train-logloss:0.0531	test-logloss:0.117173
# [700]	train-logloss:0.05075	test-logloss:0.117048
# [750]	train-logloss:0.048497	test-logloss:0.11691
# Stopping. Best iteration:
# [771]	train-logloss:0.047491	test-logloss:0.116882
#
# [0]	train-logloss:0.68459	test-logloss:0.684719
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.399324	test-logloss:0.405996
# [100]	train-logloss:0.260804	test-logloss:0.273723
# [150]	train-logloss:0.184603	test-logloss:0.203467
# [200]	train-logloss:0.139871	test-logloss:0.164288
# [250]	train-logloss:0.112427	test-logloss:0.141698
# [300]	train-logloss:0.095206	test-logloss:0.1286
# [350]	train-logloss:0.084143	test-logloss:0.12112
# [400]	train-logloss:0.076539	test-logloss:0.116735
# [450]	train-logloss:0.070949	test-logloss:0.114306
# [500]	train-logloss:0.066491	test-logloss:0.112894
# [550]	train-logloss:0.063041	test-logloss:0.112101
# [600]	train-logloss:0.06005	test-logloss:0.111629
# [650]	train-logloss:0.057507	test-logloss:0.111399
# [700]	train-logloss:0.05474	test-logloss:0.111231
# Stopping. Best iteration:
# [696]	train-logloss:0.054953	test-logloss:0.111206
#
# [0]	train-logloss:0.684521	test-logloss:0.68471
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.398981	test-logloss:0.406997
# [100]	train-logloss:0.260307	test-logloss:0.275258
# [150]	train-logloss:0.184087	test-logloss:0.205178
# [200]	train-logloss:0.139492	test-logloss:0.165924
# [250]	train-logloss:0.112254	test-logloss:0.143634
# [300]	train-logloss:0.09448	test-logloss:0.130318
# [350]	train-logloss:0.082657	test-logloss:0.122561
# [400]	train-logloss:0.074619	test-logloss:0.118092
# [450]	train-logloss:0.068509	test-logloss:0.115511
# [500]	train-logloss:0.063951	test-logloss:0.114105
# [550]	train-logloss:0.060545	test-logloss:0.113309
# [600]	train-logloss:0.057491	test-logloss:0.11287
# [650]	train-logloss:0.05453	test-logloss:0.112555
# [700]	train-logloss:0.05189	test-logloss:0.112499
# [750]	train-logloss:0.049449	test-logloss:0.112479
# Stopping. Best iteration:
# [741]	train-logloss:0.049869	test-logloss:0.112433
#
# target: 8 cultivation
# [0]	train-logloss:0.686281	test-logloss:0.686489
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.459126	test-logloss:0.468225
# [100]	train-logloss:0.349796	test-logloss:0.367222
# [150]	train-logloss:0.290133	test-logloss:0.315599
# [200]	train-logloss:0.255142	test-logloss:0.288308
# [250]	train-logloss:0.232559	test-logloss:0.273515
# [300]	train-logloss:0.217306	test-logloss:0.265307
# [350]	train-logloss:0.20611	test-logloss:0.260765
# [400]	train-logloss:0.197525	test-logloss:0.258116
# [450]	train-logloss:0.190011	test-logloss:0.256488
# [500]	train-logloss:0.183394	test-logloss:0.255488
# [550]	train-logloss:0.177746	test-logloss:0.25476
# [600]	train-logloss:0.171919	test-logloss:0.254323
# [650]	train-logloss:0.167072	test-logloss:0.254151
# [700]	train-logloss:0.162291	test-logloss:0.254008
# [750]	train-logloss:0.157611	test-logloss:0.253885
# [800]	train-logloss:0.153219	test-logloss:0.253773
# [850]	train-logloss:0.14884	test-logloss:0.253735
# Stopping. Best iteration:
# [844]	train-logloss:0.149223	test-logloss:0.253727
#
# [0]	train-logloss:0.686281	test-logloss:0.686467
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.460168	test-logloss:0.468941
# [100]	train-logloss:0.35146	test-logloss:0.368075
# [150]	train-logloss:0.29204	test-logloss:0.31648
# [200]	train-logloss:0.256606	test-logloss:0.28896
# [250]	train-logloss:0.234239	test-logloss:0.273726
# [300]	train-logloss:0.219274	test-logloss:0.265211
# [350]	train-logloss:0.208189	test-logloss:0.260361
# [400]	train-logloss:0.199432	test-logloss:0.257623
# [450]	train-logloss:0.191782	test-logloss:0.255854
# [500]	train-logloss:0.185135	test-logloss:0.254876
# [550]	train-logloss:0.179027	test-logloss:0.254217
# [600]	train-logloss:0.173876	test-logloss:0.253779
# [650]	train-logloss:0.168429	test-logloss:0.253422
# [700]	train-logloss:0.163616	test-logloss:0.25319
# Stopping. Best iteration:
# [715]	train-logloss:0.162213	test-logloss:0.253123
#
# [0]	train-logloss:0.686264	test-logloss:0.686533
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.457637	test-logloss:0.47028
# [100]	train-logloss:0.347096	test-logloss:0.370831
# [150]	train-logloss:0.286819	test-logloss:0.320723
# [200]	train-logloss:0.251028	test-logloss:0.294444
# [250]	train-logloss:0.227761	test-logloss:0.280595
# [300]	train-logloss:0.212177	test-logloss:0.272941
# [350]	train-logloss:0.200799	test-logloss:0.268876
# [400]	train-logloss:0.192296	test-logloss:0.266686
# [450]	train-logloss:0.185314	test-logloss:0.265486
# [500]	train-logloss:0.178621	test-logloss:0.264985
# [550]	train-logloss:0.172596	test-logloss:0.264598
# [600]	train-logloss:0.167321	test-logloss:0.264459
# Stopping. Best iteration:
# [613]	train-logloss:0.165983	test-logloss:0.264412
#
# target: 9 partly_cloudy
# [0]	train-logloss:0.685254	test-logloss:0.685556
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.421048	test-logloss:0.434084
# [100]	train-logloss:0.290807	test-logloss:0.314144
# [150]	train-logloss:0.2182	test-logloss:0.250004
# [200]	train-logloss:0.17474	test-logloss:0.214107
# [250]	train-logloss:0.146807	test-logloss:0.193412
# [300]	train-logloss:0.128763	test-logloss:0.18139
# [350]	train-logloss:0.116082	test-logloss:0.174197
# [400]	train-logloss:0.106745	test-logloss:0.169863
# [450]	train-logloss:0.099484	test-logloss:0.167215
# [500]	train-logloss:0.094038	test-logloss:0.165616
# [550]	train-logloss:0.089861	test-logloss:0.164487
# [600]	train-logloss:0.086421	test-logloss:0.16378
# [650]	train-logloss:0.083293	test-logloss:0.16318
# [700]	train-logloss:0.080116	test-logloss:0.162669
# [750]	train-logloss:0.076868	test-logloss:0.162217
# [800]	train-logloss:0.07366	test-logloss:0.161871
# [850]	train-logloss:0.07079	test-logloss:0.16167
# [900]	train-logloss:0.06792	test-logloss:0.161472
# [950]	train-logloss:0.065233	test-logloss:0.161343
# Stopping. Best iteration:
# [948]	train-logloss:0.065335	test-logloss:0.16132
#
# [0]	train-logloss:0.685345	test-logloss:0.685552
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.423214	test-logloss:0.433332
# [100]	train-logloss:0.293095	test-logloss:0.311986
# [150]	train-logloss:0.220297	test-logloss:0.247078
# [200]	train-logloss:0.17714	test-logloss:0.210754
# [250]	train-logloss:0.149593	test-logloss:0.189699
# [300]	train-logloss:0.131077	test-logloss:0.177327
# [350]	train-logloss:0.118067	test-logloss:0.1698
# [400]	train-logloss:0.108737	test-logloss:0.165465
# [450]	train-logloss:0.101876	test-logloss:0.162678
# [500]	train-logloss:0.096881	test-logloss:0.161102
# [550]	train-logloss:0.093017	test-logloss:0.160001
# [600]	train-logloss:0.089267	test-logloss:0.159173
# [650]	train-logloss:0.085789	test-logloss:0.158437
# [700]	train-logloss:0.082667	test-logloss:0.157843
# [750]	train-logloss:0.079435	test-logloss:0.157373
# [800]	train-logloss:0.076183	test-logloss:0.156884
# [850]	train-logloss:0.073355	test-logloss:0.15665
# [900]	train-logloss:0.070596	test-logloss:0.156374
# [950]	train-logloss:0.067921	test-logloss:0.15617
# [1000]	train-logloss:0.065448	test-logloss:0.156019
# [1050]	train-logloss:0.063197	test-logloss:0.155936
# [1100]	train-logloss:0.060836	test-logloss:0.155857
# Stopping. Best iteration:
# [1095]	train-logloss:0.061069	test-logloss:0.155833
#
# [0]	train-logloss:0.685282	test-logloss:0.685579
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.420761	test-logloss:0.434446
# [100]	train-logloss:0.290166	test-logloss:0.314394
# [150]	train-logloss:0.217207	test-logloss:0.250664
# [200]	train-logloss:0.172987	test-logloss:0.214804
# [250]	train-logloss:0.145067	test-logloss:0.19436
# [300]	train-logloss:0.126325	test-logloss:0.182615
# [350]	train-logloss:0.113711	test-logloss:0.17572
# [400]	train-logloss:0.104442	test-logloss:0.171676
# [450]	train-logloss:0.097464	test-logloss:0.169187
# [500]	train-logloss:0.092087	test-logloss:0.167542
# [550]	train-logloss:0.088109	test-logloss:0.166611
# [600]	train-logloss:0.084508	test-logloss:0.16598
# [650]	train-logloss:0.081559	test-logloss:0.165603
# [700]	train-logloss:0.078438	test-logloss:0.16513
# [750]	train-logloss:0.075377	test-logloss:0.164714
# [800]	train-logloss:0.072158	test-logloss:0.164417
# [850]	train-logloss:0.069431	test-logloss:0.1642
# [900]	train-logloss:0.066786	test-logloss:0.163959
# [950]	train-logloss:0.064446	test-logloss:0.163869
# [1000]	train-logloss:0.06209	test-logloss:0.163776
# Stopping. Best iteration:
# [994]	train-logloss:0.062392	test-logloss:0.163758
#
# target: 10 artisinal_mine
# [0]	train-logloss:0.683392	test-logloss:0.683447
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.362021	test-logloss:0.363292
# [100]	train-logloss:0.20807	test-logloss:0.210425
# [150]	train-logloss:0.124789	test-logloss:0.128182
# [200]	train-logloss:0.077188	test-logloss:0.08159
# [250]	train-logloss:0.048861	test-logloss:0.054423
# [300]	train-logloss:0.031758	test-logloss:0.038467
# [350]	train-logloss:0.021255	test-logloss:0.029017
# [400]	train-logloss:0.014698	test-logloss:0.023433
# [450]	train-logloss:0.010586	test-logloss:0.020182
# [500]	train-logloss:0.007932	test-logloss:0.018234
# [550]	train-logloss:0.006146	test-logloss:0.017081
# [600]	train-logloss:0.004942	test-logloss:0.016407
# [650]	train-logloss:0.004097	test-logloss:0.016001
# [700]	train-logloss:0.003485	test-logloss:0.01577
# [750]	train-logloss:0.003005	test-logloss:0.015646
# [800]	train-logloss:0.00263	test-logloss:0.015593
# [850]	train-logloss:0.002324	test-logloss:0.015568
# Stopping. Best iteration:
# [843]	train-logloss:0.002364	test-logloss:0.015562
#
# [0]	train-logloss:0.683368	test-logloss:0.683417
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.361952	test-logloss:0.363581
# [100]	train-logloss:0.20806	test-logloss:0.211084
# [150]	train-logloss:0.124777	test-logloss:0.129214
# [200]	train-logloss:0.077068	test-logloss:0.082808
# [250]	train-logloss:0.048823	test-logloss:0.055812
# [300]	train-logloss:0.031772	test-logloss:0.040035
# [350]	train-logloss:0.021296	test-logloss:0.030708
# [400]	train-logloss:0.014818	test-logloss:0.025251
# [450]	train-logloss:0.010715	test-logloss:0.022057
# [500]	train-logloss:0.008045	test-logloss:0.020207
# [550]	train-logloss:0.006283	test-logloss:0.019136
# [600]	train-logloss:0.005064	test-logloss:0.01852
# [650]	train-logloss:0.004195	test-logloss:0.018186
# [700]	train-logloss:0.003562	test-logloss:0.018001
# [750]	train-logloss:0.003055	test-logloss:0.017934
# [800]	train-logloss:0.002673	test-logloss:0.017898
# Stopping. Best iteration:
# [822]	train-logloss:0.002534	test-logloss:0.017887
#
# [0]	train-logloss:0.683374	test-logloss:0.68343
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.361861	test-logloss:0.363861
# [100]	train-logloss:0.208137	test-logloss:0.211512
# [150]	train-logloss:0.125154	test-logloss:0.12978
# [200]	train-logloss:0.077454	test-logloss:0.083235
# [250]	train-logloss:0.049308	test-logloss:0.056155
# [300]	train-logloss:0.032311	test-logloss:0.040121
# [350]	train-logloss:0.021816	test-logloss:0.030547
# [400]	train-logloss:0.015238	test-logloss:0.024858
# [450]	train-logloss:0.011057	test-logloss:0.021475
# [500]	train-logloss:0.008303	test-logloss:0.019432
# [550]	train-logloss:0.006479	test-logloss:0.018164
# [600]	train-logloss:0.005248	test-logloss:0.017356
# [650]	train-logloss:0.004382	test-logloss:0.016835
# [700]	train-logloss:0.003739	test-logloss:0.016549
# [750]	train-logloss:0.003243	test-logloss:0.0164
# [800]	train-logloss:0.002852	test-logloss:0.016267
# [850]	train-logloss:0.002538	test-logloss:0.016177
# [900]	train-logloss:0.002277	test-logloss:0.016166
# Stopping. Best iteration:
# [890]	train-logloss:0.002327	test-logloss:0.016142
#
# target: 11 habitation
# [0]	train-logloss:0.685099	test-logloss:0.68531
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.419924	test-logloss:0.427585
# [100]	train-logloss:0.291402	test-logloss:0.30631
# [150]	train-logloss:0.221296	test-logloss:0.242733
# [200]	train-logloss:0.180647	test-logloss:0.208268
# [250]	train-logloss:0.154823	test-logloss:0.188731
# [300]	train-logloss:0.13762	test-logloss:0.177299
# [350]	train-logloss:0.126176	test-logloss:0.170786
# [400]	train-logloss:0.118272	test-logloss:0.167003
# [450]	train-logloss:0.112044	test-logloss:0.164897
# [500]	train-logloss:0.106726	test-logloss:0.163515
# [550]	train-logloss:0.101948	test-logloss:0.162788
# [600]	train-logloss:0.097476	test-logloss:0.162264
# [650]	train-logloss:0.093261	test-logloss:0.161762
# [700]	train-logloss:0.089448	test-logloss:0.16147
# [750]	train-logloss:0.085884	test-logloss:0.161293
# [800]	train-logloss:0.082555	test-logloss:0.161115
# [850]	train-logloss:0.079027	test-logloss:0.161002
# [900]	train-logloss:0.076189	test-logloss:0.160827
# Stopping. Best iteration:
# [925]	train-logloss:0.074595	test-logloss:0.160784
#
# [0]	train-logloss:0.685151	test-logloss:0.685353
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.419218	test-logloss:0.428328
# [100]	train-logloss:0.290836	test-logloss:0.307589
# [150]	train-logloss:0.220585	test-logloss:0.24432
# [200]	train-logloss:0.178699	test-logloss:0.209233
# [250]	train-logloss:0.15248	test-logloss:0.189418
# [300]	train-logloss:0.135805	test-logloss:0.17808
# [350]	train-logloss:0.124481	test-logloss:0.171645
# [400]	train-logloss:0.116617	test-logloss:0.167948
# [450]	train-logloss:0.110364	test-logloss:0.165697
# [500]	train-logloss:0.105082	test-logloss:0.164358
# [550]	train-logloss:0.100414	test-logloss:0.16354
# [600]	train-logloss:0.096204	test-logloss:0.163066
# [650]	train-logloss:0.092132	test-logloss:0.162688
# [700]	train-logloss:0.088266	test-logloss:0.162505
# [750]	train-logloss:0.084923	test-logloss:0.162389
# Stopping. Best iteration:
# [773]	train-logloss:0.083337	test-logloss:0.162306
#
# [0]	train-logloss:0.685098	test-logloss:0.685335
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.418265	test-logloss:0.429285
# [100]	train-logloss:0.289283	test-logloss:0.308576
# [150]	train-logloss:0.218554	test-logloss:0.245161
# [200]	train-logloss:0.177042	test-logloss:0.210548
# [250]	train-logloss:0.151257	test-logloss:0.190866
# [300]	train-logloss:0.134567	test-logloss:0.179666
# [350]	train-logloss:0.123143	test-logloss:0.173223
# [400]	train-logloss:0.11486	test-logloss:0.169557
# [450]	train-logloss:0.108588	test-logloss:0.167321
# [500]	train-logloss:0.10363	test-logloss:0.165941
# [550]	train-logloss:0.09891	test-logloss:0.165004
# [600]	train-logloss:0.094774	test-logloss:0.164395
# [650]	train-logloss:0.091055	test-logloss:0.164034
# [700]	train-logloss:0.087122	test-logloss:0.163651
# [750]	train-logloss:0.083557	test-logloss:0.163373
# [800]	train-logloss:0.080104	test-logloss:0.163065
# Stopping. Best iteration:
# [825]	train-logloss:0.0784	test-logloss:0.163005
#
# target: 12 bare_ground
# [0]	train-logloss:0.683931	test-logloss:0.684003
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.38089	test-logloss:0.384029
# [100]	train-logloss:0.236733	test-logloss:0.243427
# [150]	train-logloss:0.159228	test-logloss:0.170015
# [200]	train-logloss:0.114889	test-logloss:0.130145
# [250]	train-logloss:0.088598	test-logloss:0.10821
# [300]	train-logloss:0.072301	test-logloss:0.095844
# [350]	train-logloss:0.061501	test-logloss:0.088942
# [400]	train-logloss:0.054063	test-logloss:0.085059
# [450]	train-logloss:0.049006	test-logloss:0.082873
# [500]	train-logloss:0.045205	test-logloss:0.081667
# [550]	train-logloss:0.041967	test-logloss:0.080893
# [600]	train-logloss:0.039146	test-logloss:0.080544
# [650]	train-logloss:0.0365	test-logloss:0.080312
# Stopping. Best iteration:
# [666]	train-logloss:0.035673	test-logloss:0.080266
#
# [0]	train-logloss:0.683959	test-logloss:0.683995
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.381544	test-logloss:0.384025
# [100]	train-logloss:0.237552	test-logloss:0.243046
# [150]	train-logloss:0.159955	test-logloss:0.169152
# [200]	train-logloss:0.115365	test-logloss:0.128602
# [250]	train-logloss:0.088622	test-logloss:0.106021
# [300]	train-logloss:0.072118	test-logloss:0.093084
# [350]	train-logloss:0.061243	test-logloss:0.085456
# [400]	train-logloss:0.054106	test-logloss:0.081196
# [450]	train-logloss:0.048878	test-logloss:0.078795
# [500]	train-logloss:0.045077	test-logloss:0.077392
# [550]	train-logloss:0.042054	test-logloss:0.076583
# [600]	train-logloss:0.039236	test-logloss:0.076072
# [650]	train-logloss:0.036608	test-logloss:0.075808
# [700]	train-logloss:0.034165	test-logloss:0.07569
# Stopping. Best iteration:
# [707]	train-logloss:0.033795	test-logloss:0.075683
#
# [0]	train-logloss:0.683918	test-logloss:0.684011
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.380633	test-logloss:0.384527
# [100]	train-logloss:0.236182	test-logloss:0.244018
# [150]	train-logloss:0.158481	test-logloss:0.170623
# [200]	train-logloss:0.113987	test-logloss:0.13063
# [250]	train-logloss:0.087223	test-logloss:0.108413
# [300]	train-logloss:0.070465	test-logloss:0.096064
# [350]	train-logloss:0.059606	test-logloss:0.089217
# [400]	train-logloss:0.052267	test-logloss:0.085436
# [450]	train-logloss:0.047061	test-logloss:0.083346
# [500]	train-logloss:0.043187	test-logloss:0.082207
# [550]	train-logloss:0.040134	test-logloss:0.081661
# [600]	train-logloss:0.037514	test-logloss:0.081354
# [650]	train-logloss:0.035291	test-logloss:0.081264
# Stopping. Best iteration:
# [633]	train-logloss:0.036049	test-logloss:0.081255
#
# target: 13 blow_down
# [0]	train-logloss:0.683285	test-logloss:0.683301
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359382	test-logloss:0.36007
# [100]	train-logloss:0.205408	test-logloss:0.206627
# [150]	train-logloss:0.123065	test-logloss:0.124754
# [200]	train-logloss:0.07676	test-logloss:0.078885
# [250]	train-logloss:0.050125	test-logloss:0.052669
# [300]	train-logloss:0.034404	test-logloss:0.037613
# [350]	train-logloss:0.024865	test-logloss:0.028965
# [400]	train-logloss:0.018702	test-logloss:0.02397
# [450]	train-logloss:0.01466	test-logloss:0.021208
# [500]	train-logloss:0.011862	test-logloss:0.01967
# [550]	train-logloss:0.009777	test-logloss:0.018847
# [600]	train-logloss:0.00809	test-logloss:0.018436
# [650]	train-logloss:0.006756	test-logloss:0.018278
# [700]	train-logloss:0.005709	test-logloss:0.018236
# Stopping. Best iteration:
# [705]	train-logloss:0.005618	test-logloss:0.018226
#
# [0]	train-logloss:0.683299	test-logloss:0.683289
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.360018	test-logloss:0.359581
# [100]	train-logloss:0.206409	test-logloss:0.205634
# [150]	train-logloss:0.124358	test-logloss:0.123285
# [200]	train-logloss:0.078242	test-logloss:0.076968
# [250]	train-logloss:0.051278	test-logloss:0.050284
# [300]	train-logloss:0.034975	test-logloss:0.034735
# [350]	train-logloss:0.025022	test-logloss:0.025654
# [400]	train-logloss:0.018681	test-logloss:0.020359
# [450]	train-logloss:0.014484	test-logloss:0.017311
# [500]	train-logloss:0.011521	test-logloss:0.015534
# [550]	train-logloss:0.009373	test-logloss:0.014562
# [600]	train-logloss:0.007815	test-logloss:0.014017
# [650]	train-logloss:0.006619	test-logloss:0.013696
# [700]	train-logloss:0.005658	test-logloss:0.013565
# [750]	train-logloss:0.004878	test-logloss:0.013527
# Stopping. Best iteration:
# [750]	train-logloss:0.004878	test-logloss:0.013527
#
# [0]	train-logloss:0.683304	test-logloss:0.683298
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.359937	test-logloss:0.359687
# [100]	train-logloss:0.206252	test-logloss:0.205809
# [150]	train-logloss:0.124153	test-logloss:0.12354
# [200]	train-logloss:0.078058	test-logloss:0.077291
# [250]	train-logloss:0.051273	test-logloss:0.05073
# [300]	train-logloss:0.035102	test-logloss:0.035319
# [350]	train-logloss:0.025138	test-logloss:0.026303
# [400]	train-logloss:0.018669	test-logloss:0.021104
# [450]	train-logloss:0.014402	test-logloss:0.018098
# [500]	train-logloss:0.011453	test-logloss:0.016414
# [550]	train-logloss:0.009365	test-logloss:0.015517
# [600]	train-logloss:0.007775	test-logloss:0.015063
# [650]	train-logloss:0.006535	test-logloss:0.014878
# Stopping. Best iteration:
# [669]	train-logloss:0.006134	test-logloss:0.014816
#
# target: 14 agriculture
# [0]	train-logloss:0.687515	test-logloss:0.687944
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.498885	test-logloss:0.515304
# [100]	train-logloss:0.400094	test-logloss:0.429449
# [150]	train-logloss:0.342489	test-logloss:0.382882
# [200]	train-logloss:0.305373	test-logloss:0.356029
# [250]	train-logloss:0.280358	test-logloss:0.340047
# [300]	train-logloss:0.261497	test-logloss:0.330067
# [350]	train-logloss:0.245875	test-logloss:0.323068
# [400]	train-logloss:0.233478	test-logloss:0.318679
# [450]	train-logloss:0.223598	test-logloss:0.315868
# [500]	train-logloss:0.214611	test-logloss:0.313408
# [550]	train-logloss:0.207155	test-logloss:0.311719
# [600]	train-logloss:0.201246	test-logloss:0.310566
# [650]	train-logloss:0.194946	test-logloss:0.309497
# [700]	train-logloss:0.189862	test-logloss:0.308583
# [750]	train-logloss:0.184637	test-logloss:0.307803
# [800]	train-logloss:0.179423	test-logloss:0.307153
# [850]	train-logloss:0.174038	test-logloss:0.30647
# [900]	train-logloss:0.169277	test-logloss:0.305921
# [950]	train-logloss:0.165164	test-logloss:0.305515
# [1000]	train-logloss:0.160845	test-logloss:0.305119
# [1050]	train-logloss:0.156636	test-logloss:0.30473
# [1100]	train-logloss:0.152406	test-logloss:0.304348
# [1150]	train-logloss:0.148984	test-logloss:0.304089
# [1200]	train-logloss:0.1453	test-logloss:0.30394
# [1250]	train-logloss:0.141862	test-logloss:0.303735
# Stopping. Best iteration:
# [1231]	train-logloss:0.14307	test-logloss:0.303721
#
# [0]	train-logloss:0.687675	test-logloss:0.688003
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.500124	test-logloss:0.51553
# [100]	train-logloss:0.402014	test-logloss:0.429383
# [150]	train-logloss:0.345031	test-logloss:0.383014
# [200]	train-logloss:0.307897	test-logloss:0.355964
# [250]	train-logloss:0.282718	test-logloss:0.340031
# [300]	train-logloss:0.263802	test-logloss:0.329771
# [350]	train-logloss:0.249226	test-logloss:0.323208
# [400]	train-logloss:0.236597	test-logloss:0.318353
# [450]	train-logloss:0.225845	test-logloss:0.314926
# [500]	train-logloss:0.216036	test-logloss:0.31205
# [550]	train-logloss:0.208463	test-logloss:0.310253
# [600]	train-logloss:0.202233	test-logloss:0.308912
# [650]	train-logloss:0.1956	test-logloss:0.307635
# [700]	train-logloss:0.190027	test-logloss:0.306687
# [750]	train-logloss:0.184872	test-logloss:0.305761
# [800]	train-logloss:0.180086	test-logloss:0.305102
# [850]	train-logloss:0.175599	test-logloss:0.30453
# [900]	train-logloss:0.171063	test-logloss:0.303962
# [950]	train-logloss:0.166803	test-logloss:0.303576
# [1000]	train-logloss:0.162877	test-logloss:0.303064
# [1050]	train-logloss:0.158996	test-logloss:0.302659
# [1100]	train-logloss:0.155166	test-logloss:0.302391
# [1150]	train-logloss:0.151237	test-logloss:0.302098
# [1200]	train-logloss:0.147721	test-logloss:0.301813
# [1250]	train-logloss:0.144386	test-logloss:0.301611
# [1300]	train-logloss:0.141	test-logloss:0.301395
# [1350]	train-logloss:0.137984	test-logloss:0.301196
# [1400]	train-logloss:0.134884	test-logloss:0.300987
# [1450]	train-logloss:0.131714	test-logloss:0.300919
# [1500]	train-logloss:0.128361	test-logloss:0.300771
# Stopping. Best iteration:
# [1496]	train-logloss:0.128632	test-logloss:0.30076
#
# [0]	train-logloss:0.687552	test-logloss:0.687899
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.500249	test-logloss:0.514084
# [100]	train-logloss:0.402939	test-logloss:0.427492
# [150]	train-logloss:0.346328	test-logloss:0.380497
# [200]	train-logloss:0.309432	test-logloss:0.352841
# [250]	train-logloss:0.284381	test-logloss:0.335972
# [300]	train-logloss:0.265796	test-logloss:0.324989
# [350]	train-logloss:0.251133	test-logloss:0.317788
# [400]	train-logloss:0.23883	test-logloss:0.312688
# [450]	train-logloss:0.227801	test-logloss:0.30883
# [500]	train-logloss:0.219402	test-logloss:0.30628
# [550]	train-logloss:0.211976	test-logloss:0.304271
# [600]	train-logloss:0.205144	test-logloss:0.302709
# [650]	train-logloss:0.199487	test-logloss:0.301608
# [700]	train-logloss:0.193803	test-logloss:0.300393
# [750]	train-logloss:0.188753	test-logloss:0.299536
# [800]	train-logloss:0.183873	test-logloss:0.298784
# [850]	train-logloss:0.178787	test-logloss:0.298039
# [900]	train-logloss:0.174198	test-logloss:0.297444
# [950]	train-logloss:0.169712	test-logloss:0.296771
# [1000]	train-logloss:0.165372	test-logloss:0.296179
# [1050]	train-logloss:0.161375	test-logloss:0.295718
# [1100]	train-logloss:0.157427	test-logloss:0.29534
# [1150]	train-logloss:0.153535	test-logloss:0.294849
# [1200]	train-logloss:0.149668	test-logloss:0.294441
# [1250]	train-logloss:0.146097	test-logloss:0.29405
# [1300]	train-logloss:0.142543	test-logloss:0.293706
# [1350]	train-logloss:0.139081	test-logloss:0.293349
# [1400]	train-logloss:0.135836	test-logloss:0.293174
# [1450]	train-logloss:0.132891	test-logloss:0.293032
# [1500]	train-logloss:0.130051	test-logloss:0.292927
# [1550]	train-logloss:0.127098	test-logloss:0.292812
# [1600]	train-logloss:0.124368	test-logloss:0.29262
# Stopping. Best iteration:
# [1620]	train-logloss:0.123329	test-logloss:0.292583
#
# target: 15 road
# [0]	train-logloss:0.686872	test-logloss:0.687216
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.477445	test-logloss:0.491974
# [100]	train-logloss:0.371759	test-logloss:0.398461
# [150]	train-logloss:0.311146	test-logloss:0.348636
# [200]	train-logloss:0.274103	test-logloss:0.320924
# [250]	train-logloss:0.250514	test-logloss:0.305422
# [300]	train-logloss:0.234109	test-logloss:0.296588
# [350]	train-logloss:0.22152	test-logloss:0.291015
# [400]	train-logloss:0.211835	test-logloss:0.287523
# [450]	train-logloss:0.203328	test-logloss:0.285285
# [500]	train-logloss:0.19509	test-logloss:0.283584
# [550]	train-logloss:0.187643	test-logloss:0.282303
# [600]	train-logloss:0.181462	test-logloss:0.281328
# [650]	train-logloss:0.175857	test-logloss:0.280588
# [700]	train-logloss:0.170209	test-logloss:0.279957
# [750]	train-logloss:0.165189	test-logloss:0.279536
# [800]	train-logloss:0.160869	test-logloss:0.279222
# [850]	train-logloss:0.156692	test-logloss:0.278941
# [900]	train-logloss:0.152956	test-logloss:0.278707
# [950]	train-logloss:0.148783	test-logloss:0.278537
# [1000]	train-logloss:0.144503	test-logloss:0.27845
# Stopping. Best iteration:
# [1003]	train-logloss:0.144246	test-logloss:0.278415
#
# [0]	train-logloss:0.686833	test-logloss:0.68722
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.478263	test-logloss:0.491942
# [100]	train-logloss:0.372227	test-logloss:0.397499
# [150]	train-logloss:0.311907	test-logloss:0.34695
# [200]	train-logloss:0.275013	test-logloss:0.318579
# [250]	train-logloss:0.251132	test-logloss:0.302292
# [300]	train-logloss:0.234847	test-logloss:0.292897
# [350]	train-logloss:0.222745	test-logloss:0.287016
# [400]	train-logloss:0.213115	test-logloss:0.28335
# [450]	train-logloss:0.203841	test-logloss:0.280747
# [500]	train-logloss:0.19623	test-logloss:0.279019
# [550]	train-logloss:0.189067	test-logloss:0.277608
# [600]	train-logloss:0.183006	test-logloss:0.276699
# [650]	train-logloss:0.17722	test-logloss:0.275878
# [700]	train-logloss:0.171637	test-logloss:0.275178
# [750]	train-logloss:0.166913	test-logloss:0.274764
# [800]	train-logloss:0.162265	test-logloss:0.274307
# [850]	train-logloss:0.157928	test-logloss:0.274
# [900]	train-logloss:0.153714	test-logloss:0.273735
# [950]	train-logloss:0.149963	test-logloss:0.273506
# Stopping. Best iteration:
# [977]	train-logloss:0.148062	test-logloss:0.273463
#
# [0]	train-logloss:0.68692	test-logloss:0.687299
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.47701	test-logloss:0.493344
# [100]	train-logloss:0.370678	test-logloss:0.400114
# [150]	train-logloss:0.310382	test-logloss:0.350919
# [200]	train-logloss:0.27361	test-logloss:0.323359
# [250]	train-logloss:0.249865	test-logloss:0.307887
# [300]	train-logloss:0.233871	test-logloss:0.299074
# [350]	train-logloss:0.221928	test-logloss:0.293881
# [400]	train-logloss:0.21191	test-logloss:0.2904
# [450]	train-logloss:0.203817	test-logloss:0.288424
# [500]	train-logloss:0.196954	test-logloss:0.287116
# [550]	train-logloss:0.190339	test-logloss:0.28613
# [600]	train-logloss:0.18339	test-logloss:0.285346
# [650]	train-logloss:0.176915	test-logloss:0.284651
# [700]	train-logloss:0.171695	test-logloss:0.284219
# [750]	train-logloss:0.166804	test-logloss:0.283784
# [800]	train-logloss:0.162084	test-logloss:0.283426
# [850]	train-logloss:0.157753	test-logloss:0.283174
# Stopping. Best iteration:
# [866]	train-logloss:0.156331	test-logloss:0.283045
#
# target: 16 selective_logging
# [0]	train-logloss:0.683522	test-logloss:0.68353
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367214	test-logloss:0.368135
# [100]	train-logloss:0.216846	test-logloss:0.219014
# [150]	train-logloss:0.136127	test-logloss:0.139969
# [200]	train-logloss:0.090197	test-logloss:0.095985
# [250]	train-logloss:0.063006	test-logloss:0.070966
# [300]	train-logloss:0.046367	test-logloss:0.056632
# [350]	train-logloss:0.03582	test-logloss:0.048459
# [400]	train-logloss:0.02891	test-logloss:0.043739
# [450]	train-logloss:0.024252	test-logloss:0.041047
# [500]	train-logloss:0.021122	test-logloss:0.039537
# [550]	train-logloss:0.018912	test-logloss:0.038692
# [600]	train-logloss:0.017242	test-logloss:0.038189
# [650]	train-logloss:0.015816	test-logloss:0.037957
# [700]	train-logloss:0.014553	test-logloss:0.037803
# Stopping. Best iteration:
# [714]	train-logloss:0.014233	test-logloss:0.037752
#
# [0]	train-logloss:0.68353	test-logloss:0.683529
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367404	test-logloss:0.367958
# [100]	train-logloss:0.217072	test-logloss:0.218654
# [150]	train-logloss:0.136482	test-logloss:0.139501
# [200]	train-logloss:0.09062	test-logloss:0.095488
# [250]	train-logloss:0.063476	test-logloss:0.070388
# [300]	train-logloss:0.046968	test-logloss:0.055935
# [350]	train-logloss:0.036685	test-logloss:0.047542
# [400]	train-logloss:0.03001	test-logloss:0.042729
# [450]	train-logloss:0.025648	test-logloss:0.03997
# [500]	train-logloss:0.022577	test-logloss:0.038378
# [550]	train-logloss:0.020408	test-logloss:0.037537
# [600]	train-logloss:0.018773	test-logloss:0.037058
# [650]	train-logloss:0.017323	test-logloss:0.036807
# [700]	train-logloss:0.016055	test-logloss:0.036622
# [750]	train-logloss:0.014799	test-logloss:0.036554
# Stopping. Best iteration:
# [762]	train-logloss:0.014521	test-logloss:0.036541
#
# [0]	train-logloss:0.683517	test-logloss:0.683534
# Multiple eval metrics have been passed: 'test-logloss' will be used for early stopping.
#
# Will train until test-logloss hasn't improved in 20 rounds.
# [50]	train-logloss:0.367331	test-logloss:0.367915
# [100]	train-logloss:0.216707	test-logloss:0.218493
# [150]	train-logloss:0.135891	test-logloss:0.139236
# [200]	train-logloss:0.089897	test-logloss:0.095222
# [250]	train-logloss:0.062756	test-logloss:0.070219
# [300]	train-logloss:0.046038	test-logloss:0.055943
# [350]	train-logloss:0.035624	test-logloss:0.047892
# [400]	train-logloss:0.029007	test-logloss:0.043352
# [450]	train-logloss:0.024657	test-logloss:0.040855
# [500]	train-logloss:0.021742	test-logloss:0.039571
# [550]	train-logloss:0.019498	test-logloss:0.038858
# [600]	train-logloss:0.017833	test-logloss:0.038511
# [650]	train-logloss:0.016433	test-logloss:0.038394
# [700]	train-logloss:0.015126	test-logloss:0.03834
# Stopping. Best iteration:
# [704]	train-logloss:0.015028	test-logloss:0.038333
#
# bestRounds:
# {0: 660, 1: 1143, 2: 692, 3: 730, 4: 888, 5: 725, 6: 1150, 7: 741, 8: 613, 9: 994, 10: 890, 11: 825, 12: 633, 13: 669, 14: 1620, 15: 866, 16: 704}

# %%
# xgboost predict




predsDF = pd.DataFrame()
for i in range(0,17):
    print ('predicting feature ' + str(i))
    Y_train = Y_trainAll.ix[:,i]
    #print (Y_train.shape)
    preds, model, br = runXGB(X_train, Y_train, X_test, num_rounds=int(brDict[i]*1.33))
    predsDF[i] = preds

print (predsDF.shape)
# Out:
# predicting feature 0
# predicting feature 1
# predicting feature 2
# predicting feature 3
# predicting feature 4
# predicting feature 5
# predicting feature 6
# predicting feature 7
# predicting feature 8
# predicting feature 9
# predicting feature 10
# predicting feature 11
# predicting feature 12
# predicting feature 13
# predicting feature 14
# predicting feature 15
# predicting feature 16
# (40669, 17)

# %%
i = xgb.importance(model=model)
print (i)

# %%
print (predsDF.head())
print (X_train_id[0:5])

# %%
# predsDF to prediction file

def mapf (arr):
    res = ''
    for i in range(0,17):
        if arr[i] > 0.5:
            res += inv_label_map[i] + ' '
    res = res.rstrip()
    return res

print(predsDF.shape)

textResults = []

for i, row in predsDF.iterrows():
    #print (i)
    #print (list(row))
    textResults.append ( mapf( list (row)))
    
print (textResults[0:5])

res = pd.DataFrame()
res['image_name'] = X_test_id
res['tags'] = textResults

print (res.head())

res.to_csv('SUB_25_0.01eta.csv', index=False)

# %%
predsDF.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.001509  0.972671  0.047312  0.999827  0.000085  0.000065  0.042768
# 1  0.001760  0.989465  0.002570  0.999623  0.000230  0.000114  0.059147
# 2  0.006104  0.973876  0.005513  0.998994  0.000235  0.000189  0.639454
# 3  0.012243  0.935445  0.001582  0.995544  0.000567  0.000693  0.828803
# 4  0.002334  0.018530  0.005153  0.998468  0.000225  0.000387  0.094218
#
#           7         8         9        10        11        12        13  \
# 0  0.000434  0.438457  0.011927  0.000021  0.017920  0.005873  0.003358
# 1  0.001212  0.020107  0.004467  0.000177  0.001416  0.001669  0.001612
# 2  0.007449  0.048404  0.010324  0.000073  0.013641  0.004402  0.001366
# 3  0.008132  0.146062  0.035113  0.001794  0.067513  0.020096  0.000648
# 4  0.026948  0.027737  0.964892  0.000227  0.013253  0.009426  0.003657
#
#          14        15        16          id
# 0  0.719696  0.074135  0.029849  test_34045
# 1  0.052388  0.010477  0.001279  test_32937
# 2  0.074483  0.047072  0.003743  test_10537
# 3  0.143409  0.116787  0.005036  test_30945
# 4  0.038879  0.036904  0.002558  test_13470

# %%
# save RAW

predsDF['id'] = X_test_id
predsDF.to_csv('RAW_25.csv', index=False)
